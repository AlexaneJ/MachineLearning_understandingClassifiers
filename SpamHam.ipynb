# %% [markdown]
# # Jeu de données 2 : Spam or ham?

# %%
# 0 indique que ce n'est pas un spam
# 1 indique que c'est un spam

# %% [markdown]
# ## Lecture du jeu de données et comptes

# %%
import pandas as pd
data_spam = pd.read_csv("spamham.csv")

# %%
texte = data_spam["text"]
print("Le texte comporte", len(texte), "mails.")
# Out:
# Le texte comporte 5728 mails.

# %%
import nltk
from nltk.tokenize import word_tokenize
# tokenizer comprenant les mots avec une apostrophe (l', qu') et les ponctuations séparément
# une telle tokenization nous permet d'avoir une bonne idée du nombre de token
nb_instances= 0
for i in texte:
    l=len(word_tokenize(i))
    nb_instances+=l
print("Il y a", nb_instances, " tokens en incluant la ponctuation.") # nombre de tokens avec ponctuation

import re
nb_instances2= 0
for i in texte:
    j = re.sub(",|;|\.", " ", i)
    l2=len(word_tokenize(j))
    nb_instances2 += l2
print("Il y a", nb_instances2, " tokens sans inclure la ponctuation.") # nombre de tokens sans ponctuation

from nltk.tokenize import sent_tokenize
nb_instances3= 0
for i in texte:
    longueur_text=len(sent_tokenize(i))
    nb_instances3 += longueur_text
print("Il y a", nb_instances3, "phrases dans l'ensemble du corpus.")
# Out:
# Il y a 1878684  tokens en incluant la ponctuation.
# Il y a 1722545  tokens sans inclure la ponctuation.
# Il y a 111600 phrases dans l'ensemble du corpus.

# %%
#1368 spams
ham = 5728-1368
print("Il y a 1368 spams au total et", ham, "hams")
# Out:
# Il y a 1368 spams au total et 4360 hams

# %% [markdown]
# ## Vectorisation du jeu de données

# %%
mail = data_spam["text"]
print(mail)
# Out:
# 0       Subject: naturally irresistible your corporate...
# 1       Subject: the stock trading gunslinger  fanny i...
# 2       Subject: unbelievable new homes made easy  im ...
# 3       Subject: 4 color printing special  request add...
# 4       Subject: do not have money , get software cds ...
#                               ...
# 5723    Subject: re : research and development charges...
# 5724    Subject: re : receipts from visit  jim ,  than...
# 5725    Subject: re : enron case study update  wow ! a...
# 5726    Subject: re : interest  david ,  please , call...
# 5727    Subject: news : aurora 5 . 2 update  aurora ve...
# Name: text, Length: 5728, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
## Récupérer les instances (X) et les classes (y) et vectoriser
y = data_spam["spam"]
V = CountVectorizer(ngram_range = (1,2) )
X = V.fit_transform(data_spam["text"])

## séparer train test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
test = 0.3*5728
train = 5728 - test

# %%
print("0,3 pour la taille du test soit environ", test, "mails. Donc environ", train, "mails pour le train.")
# Out:
# 0,3 pour la taille du test soit environ 1718.3999999999999 mails. Donc environ 4009.6000000000004 mails pour le train.

# %% [markdown]
# ## Classifications et Evaluations

# %% [markdown]
# ### Le perceptron, réseau de neurones simple, classifieur linéaire

# %%
#classifier
from sklearn.linear_model import Perceptron

ppn = Perceptron(eta0=0.1, random_state=0)
ppn.fit(X_train, y_train)
y_pred = ppn.predict(X_test)

# On fait la somme de tous les cas où la valeur dans y_test est bien trouvée dans y_pred
print('Bons résultats %d' % (y_test == y_pred).sum())
print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# Bons résultats 1685
# Erreurs: 34

# %% [markdown]
# **Les données de classification : elles permettent d'évaluer la qualité de la classification. Ici, on calcule ces données avec les résultats donnés par le Perceptron.**

# %%
from sklearn.metrics import classification_report
#Classification report permet de msurer l'exactitude d'une clissification selon plusieurs paramètres

nom_classes = ["ham", "spam"]
report = classification_report(y_test, y_pred, target_names=nom_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      0.98      0.99      1314
#         spam       0.95      0.97      0.96       405
#
#     accuracy                           0.98      1719
#    macro avg       0.97      0.98      0.97      1719
# weighted avg       0.98      0.98      0.98      1719

# %%
# la précision est la proportion des items pertinents parmi l'ensemble des items proposés

# %%
# le rappel est la proportion des items pertinents proposés parmi l'ensemble des items pertinents.

# %%
# Vrai négatif : absent, absent
# Vrai positif : présent, présent
# Faux négatif : présent(dans la référence), absent(dans l'hypothèse)
# Faux positif : absent, présent

# %%
# support : nombre d'instances concernées

# micro f-mesure : moyenne des F-mesure pondérée (une classe compte en fonction de sa taille)

# macro f-mesure : moyenne des F-mesure de chaque classe (indépendamment de leur taille)

# %%
#La matrice de confusion
from sklearn.metrics import confusion_matrix

matrice_confusion = confusion_matrix(y_test, y_pred)
print(matrice_confusion)
# Out:
# [[1256   58]
#  [  33  372]]

# %%
# de gauche à droite et de bas en haut : 
# ham, spam
# spam, ham

# %% [markdown]
# ### Deuxième évaluation : Un arbre de décision

# %%
from sklearn import tree
DT = tree.DecisionTreeClassifier()
DT = DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)

# %%
# encore une matrice de confusion
matrice_confusion = confusion_matrix(y_test, y_pred)
print(matrice_confusion)

print('Bons résultats %d' % (y_test == y_pred).sum())
print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# [[1256   58]
#  [  33  372]]
# Bons résultats 1628
# Erreurs: 91

# %%
from sklearn.metrics import classification_report
#Classification report permet de msurer l'exactitude d'une clissification selon plusieurs paramètres

nom_classes = ["ham", "spam"]
report = classification_report(y_test, y_pred, target_names=nom_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      0.96      0.97      1314
#         spam       0.87      0.92      0.89       405
#
#     accuracy                           0.95      1719
#    macro avg       0.92      0.94      0.93      1719
# weighted avg       0.95      0.95      0.95      1719

# %%
# résultats moins bons que précédemment.

# %% [markdown]
# ## Approfondissement

# %% [markdown]
# **Regardons l'impact du paramètres random_state**

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support

# %%
print("Avec la valeur par défaut de random state")
for i in range(3):
  DT = tree.DecisionTreeClassifier()
  DT = DT.fit(X_train, y_train)
  y_pred = DT.predict(X_test)
  matrice_confusion = confusion_matrix(y_test, y_pred)
  print(matrice_confusion)
  stats = precision_recall_fscore_support(y_test, y_pred)
  print(stats)
  print('Bons résultats %d' % (y_test == y_pred).sum())
  print('Erreurs: %d' % (y_test != y_pred).sum())
  print("--"*10)
# Out:
# Avec la valeur par défaut de random state
# [[1260   54]
#  [  30  375]]
# (array([0.97674419, 0.87412587]), array([0.95890411, 0.92592593]), array([0.96774194, 0.89928058]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# --------------------
# [[1253   61]
#  [  34  371]]
# (array([0.97358197, 0.8587963 ]), array([0.95357686, 0.91604938]), array([0.96347559, 0.8864994 ]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# --------------------
# [[1260   54]
#  [  35  370]]
# (array([0.97297297, 0.87264151]), array([0.95890411, 0.91358025]), array([0.96588731, 0.89264174]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# --------------------

# %%
from sklearn.metrics import accuracy_score
print ('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.95

# %%
print("En fixant random state")
for i in range(3):
  DT = tree.DecisionTreeClassifier(random_state=0)
  DT = DT.fit(X_train, y_train)
  y_pred = DT.predict(X_test)
  matrice_confusion = confusion_matrix(y_test, y_pred)
  print(matrice_confusion)
  stats = precision_recall_fscore_support(y_test, y_pred)
  print(stats)
  print('Bons résultats %d' % (y_test == y_pred).sum())
  print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# En fixant random state
# [[1261   53]
#  [  37  368]]
# (array([0.97149461, 0.87410926]), array([0.95966514, 0.90864198]), array([0.96554364, 0.89104116]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# [[1261   53]
#  [  37  368]]
# (array([0.97149461, 0.87410926]), array([0.95966514, 0.90864198]), array([0.96554364, 0.89104116]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# [[1261   53]
#  [  37  368]]
# (array([0.97149461, 0.87410926]), array([0.95966514, 0.90864198]), array([0.96554364, 0.89104116]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90

# %%
print ('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.95

# %% [markdown]
# **Différents paramètres que l'on peut faire varier : max_depth, min_samples_split, min_samples_leaf et max_features**

# %%
print("On teste max_depth")
for i in range(1, 100):
  DT = tree.DecisionTreeClassifier(max_depth=i)
  DT = DT.fit(X_train, y_train)
  y_pred = DT.predict(X_test)
  matrice_confusion = confusion_matrix(y_test, y_pred)
  print("Avec max_depth=", i)
  print(matrice_confusion)
  stats = precision_recall_fscore_support(y_test, y_pred)
  print(stats)
  print('Bons résultats %d' % (y_test == y_pred).sum())
  print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# On teste max_depth
# Avec max_depth= 1
# [[1314    0]
#  [ 405    0]]
# (array([0.76439791, 0.        ]), array([1., 0.]), array([0.86646884, 0.        ]), array([1314,  405]))
# Bons résultats 1314
# Erreurs: 405
# Avec max_depth= 2
# [[1036  278]
#  [   1  404]]
# (array([0.99903568, 0.59237537]), array([0.78843227, 0.99753086]), array([0.88132709, 0.74333027]), array([1314,  405]))
# Bons résultats 1440
# Erreurs: 279
# Avec max_depth= 3
# [[1089  225]
#  [  11  394]]
# (array([0.99     , 0.6365105]), array([0.82876712, 0.97283951]), array([0.90223695, 0.76953125]), array([1314,  405]))
# Bons résultats 1483
# Erreurs: 236
# Avec max_depth= 4
# [[1229   85]
#  [ 132  273]]
# (array([0.90301249, 0.76256983]), array([0.93531202, 0.67407407]), array([0.9188785 , 0.71559633]), array([1314,  405]))
# Bons résultats 1502
# Erreurs: 217
# Avec max_depth= 5
# [[1133  181]
#  [   5  400]]
# (array([0.99560633, 0.68846816]), array([0.86225266, 0.98765432]), array([0.92414356, 0.81135903]), array([1314,  405]))
# Bons résultats 1533
# Erreurs: 186
# Avec max_depth= 6
# [[1184  130]
#  [  32  373]]
# (array([0.97368421, 0.7415507 ]), array([0.90106545, 0.92098765]), array([0.93596838, 0.8215859 ]), array([1314,  405]))
# Bons résultats 1557
# Erreurs: 162
# Avec max_depth= 7
# [[1201  113]
#  [  25  380]]
# (array([0.97960848, 0.77079108]), array([0.91400304, 0.9382716 ]), array([0.94566929, 0.84632517]), array([1314,  405]))
# Bons résultats 1581
# Erreurs: 138
# Avec max_depth= 8
# [[1212  102]
#  [  28  377]]
# (array([0.97741935, 0.78705637]), array([0.92237443, 0.9308642 ]), array([0.94909945, 0.85294118]), array([1314,  405]))
# Bons résultats 1589
# Erreurs: 130
# Avec max_depth= 9
# [[1221   93]
#  [  25  380]]
# (array([0.97993579, 0.80338266]), array([0.92922374, 0.9382716 ]), array([0.95390625, 0.86560364]), array([1314,  405]))
# Bons résultats 1601
# Erreurs: 118
# Avec max_depth= 10
# [[1225   89]
#  [  28  377]]
# (array([0.97765363, 0.80901288]), array([0.93226788, 0.9308642 ]), array([0.9544215 , 0.86567164]), array([1314,  405]))
# Bons résultats 1602
# Erreurs: 117
# Avec max_depth= 11
# [[1232   82]
#  [  27  378]]
# (array([0.97855441, 0.82173913]), array([0.93759513, 0.93333333]), array([0.957637  , 0.87398844]), array([1314,  405]))
# Bons résultats 1610
# Erreurs: 109
# Avec max_depth= 12
# [[1239   75]
#  [  23  382]]
# (array([0.98177496, 0.83588621]), array([0.94292237, 0.94320988]), array([0.96195652, 0.8863109 ]), array([1314,  405]))
# Bons résultats 1621
# Erreurs: 98
# Avec max_depth= 13
# [[1245   69]
#  [  33  372]]
# (array([0.9741784 , 0.84353741]), array([0.94748858, 0.91851852]), array([0.96064815, 0.87943262]), array([1314,  405]))
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth= 14
# [[1242   72]
#  [  29  376]]
# (array([0.97718332, 0.83928571]), array([0.94520548, 0.92839506]), array([0.96092843, 0.88159437]), array([1314,  405]))
# Bons résultats 1618
# Erreurs: 101
# Avec max_depth= 15
# [[1241   73]
#  [  27  378]]
# (array([0.97870662, 0.83813747]), array([0.94444444, 0.93333333]), array([0.96127033, 0.88317757]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 16
# [[1248   66]
#  [  28  377]]
# (array([0.97805643, 0.8510158 ]), array([0.94977169, 0.9308642 ]), array([0.96370656, 0.88915094]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 17
# [[1253   61]
#  [  30  375]]
# (array([0.9766173 , 0.86009174]), array([0.95357686, 0.92592593]), array([0.96495957, 0.89179548]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 18
# [[1249   65]
#  [  26  379]]
# (array([0.97960784, 0.8536036 ]), array([0.95053272, 0.93580247]), array([0.96485129, 0.89281508]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 19
# [[1249   65]
#  [  32  373]]
# (array([0.97501952, 0.85159817]), array([0.95053272, 0.92098765]), array([0.96262042, 0.88493476]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 20
# [[1256   58]
#  [  34  371]]
# (array([0.97364341, 0.86480186]), array([0.95585997, 0.91604938]), array([0.96466974, 0.88968825]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 21
# [[1251   63]
#  [  30  375]]
# (array([0.9765808 , 0.85616438]), array([0.95205479, 0.92592593]), array([0.96416185, 0.88967972]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 22
# [[1253   61]
#  [  33  372]]
# (array([0.97433904, 0.8591224 ]), array([0.95357686, 0.91851852]), array([0.96384615, 0.88782816]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 23
# [[1255   59]
#  [  28  377]]
# (array([0.97817615, 0.8646789 ]), array([0.95509893, 0.9308642 ]), array([0.96649981, 0.89655172]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 24
# [[1261   53]
#  [  33  372]]
# (array([0.97449768, 0.87529412]), array([0.95966514, 0.91851852]), array([0.96702454, 0.89638554]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 25
# [[1257   57]
#  [  35  370]]
# (array([0.97291022, 0.86651054]), array([0.956621  , 0.91358025]), array([0.96469685, 0.88942308]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 26
# [[1255   59]
#  [  35  370]]
# (array([0.97286822, 0.86247086]), array([0.95509893, 0.91358025]), array([0.96390169, 0.88729017]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 27
# [[1258   56]
#  [  33  372]]
# (array([0.97443842, 0.86915888]), array([0.95738204, 0.91851852]), array([0.96583493, 0.89315726]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 28
# [[1262   52]
#  [  31  374]]
# (array([0.97602475, 0.87793427]), array([0.96042618, 0.92345679]), array([0.96816264, 0.90012034]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 29
# [[1251   63]
#  [  31  374]]
# (array([0.97581903, 0.85583524]), array([0.95205479, 0.92345679]), array([0.96379045, 0.88836105]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 30
# [[1261   53]
#  [  30  375]]
# (array([0.9767622 , 0.87616822]), array([0.95966514, 0.92592593]), array([0.9681382 , 0.90036014]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 31
# [[1250   64]
#  [  32  373]]
# (array([0.975039  , 0.85354691]), array([0.95129376, 0.92098765]), array([0.96302003, 0.88598575]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 32
# [[1255   59]
#  [  42  363]]
# (array([0.96761758, 0.86018957]), array([0.95509893, 0.8962963 ]), array([0.9613175 , 0.87787183]), array([1314,  405]))
# Bons résultats 1618
# Erreurs: 101
# Avec max_depth= 33
# [[1259   55]
#  [  35  370]]
# (array([0.97295209, 0.87058824]), array([0.95814307, 0.91358025]), array([0.9654908 , 0.89156627]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 34
# [[1258   56]
#  [  34  371]]
# (array([0.97368421, 0.86885246]), array([0.95738204, 0.91604938]), array([0.96546431, 0.89182692]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 35
# [[1249   65]
#  [  31  374]]
# (array([0.97578125, 0.85193622]), array([0.95053272, 0.92345679]), array([0.96299152, 0.88625592]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 36
# [[1256   58]
#  [  25  380]]
# (array([0.980484  , 0.86757991]), array([0.95585997, 0.9382716 ]), array([0.96801541, 0.90154211]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 37
# [[1255   59]
#  [  28  377]]
# (array([0.97817615, 0.8646789 ]), array([0.95509893, 0.9308642 ]), array([0.96649981, 0.89655172]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 38
# [[1257   57]
#  [  33  372]]
# (array([0.9744186 , 0.86713287]), array([0.956621  , 0.91851852]), array([0.96543779, 0.89208633]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 39
# [[1250   64]
#  [  27  378]]
# (array([0.9788567 , 0.85520362]), array([0.95129376, 0.93333333]), array([0.96487843, 0.89256198]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 40
# [[1253   61]
#  [  33  372]]
# (array([0.97433904, 0.8591224 ]), array([0.95357686, 0.91851852]), array([0.96384615, 0.88782816]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 41
# [[1262   52]
#  [  41  364]]
# (array([0.96853415, 0.875     ]), array([0.96042618, 0.89876543]), array([0.96446313, 0.88672351]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 42
# [[1257   57]
#  [  31  374]]
# (array([0.97593168, 0.86774942]), array([0.956621  , 0.92345679]), array([0.96617986, 0.89473684]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 43
# [[1254   60]
#  [  35  370]]
# (array([0.97284717, 0.86046512]), array([0.9543379 , 0.91358025]), array([0.96350365, 0.88622754]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 44
# [[1252   62]
#  [  31  374]]
# (array([0.97583788, 0.85779817]), array([0.95281583, 0.92345679]), array([0.96418945, 0.88941736]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 45
# [[1258   56]
#  [  29  376]]
# (array([0.97746698, 0.87037037]), array([0.95738204, 0.92839506]), array([0.96732026, 0.89844683]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 46
# [[1250   64]
#  [  32  373]]
# (array([0.975039  , 0.85354691]), array([0.95129376, 0.92098765]), array([0.96302003, 0.88598575]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 47
# [[1262   52]
#  [  34  371]]
# (array([0.97376543, 0.87706856]), array([0.96042618, 0.91604938]), array([0.96704981, 0.89613527]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 48
# [[1251   63]
#  [  29  376]]
# (array([0.97734375, 0.85649203]), array([0.95205479, 0.92839506]), array([0.96453354, 0.89099526]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 49
# [[1259   55]
#  [  34  371]]
# (array([0.97370456, 0.87089202]), array([0.95814307, 0.91604938]), array([0.96586114, 0.89290012]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 50
# [[1252   62]
#  [  33  372]]
# (array([0.97431907, 0.85714286]), array([0.95281583, 0.91851852]), array([0.96344748, 0.88676996]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 51
# [[1252   62]
#  [  34  371]]
# (array([0.97356143, 0.85681293]), array([0.95281583, 0.91604938]), array([0.96307692, 0.88544153]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 52
# [[1260   54]
#  [  29  376]]
# (array([0.97750194, 0.8744186 ]), array([0.95890411, 0.92839506]), array([0.96811371, 0.9005988 ]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 53
# [[1258   56]
#  [  29  376]]
# (array([0.97746698, 0.87037037]), array([0.95738204, 0.92839506]), array([0.96732026, 0.89844683]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 54
# [[1256   58]
#  [  33  372]]
# (array([0.97439876, 0.86511628]), array([0.95585997, 0.91851852]), array([0.96504034, 0.89101796]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 55
# [[1249   65]
#  [  32  373]]
# (array([0.97501952, 0.85159817]), array([0.95053272, 0.92098765]), array([0.96262042, 0.88493476]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 56
# [[1258   56]
#  [  37  368]]
# (array([0.97142857, 0.86792453]), array([0.95738204, 0.90864198]), array([0.96435416, 0.88781665]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 57
# [[1254   60]
#  [  35  370]]
# (array([0.97284717, 0.86046512]), array([0.9543379 , 0.91358025]), array([0.96350365, 0.88622754]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 58
# [[1258   56]
#  [  34  371]]
# (array([0.97368421, 0.86885246]), array([0.95738204, 0.91604938]), array([0.96546431, 0.89182692]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 59
# [[1259   55]
#  [  33  372]]
# (array([0.9744582 , 0.87119438]), array([0.95814307, 0.91851852]), array([0.96623177, 0.89423077]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 60
# [[1251   63]
#  [  36  369]]
# (array([0.97202797, 0.85416667]), array([0.95205479, 0.91111111]), array([0.96193772, 0.88172043]), array([1314,  405]))
# Bons résultats 1620
# Erreurs: 99
# Avec max_depth= 61
# [[1260   54]
#  [  43  362]]
# (array([0.96699923, 0.87019231]), array([0.95890411, 0.89382716]), array([0.96293466, 0.8818514 ]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 62
# [[1261   53]
#  [  32  373]]
# (array([0.97525135, 0.87558685]), array([0.95966514, 0.92098765]), array([0.96739547, 0.8977136 ]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 63
# [[1252   62]
#  [  30  375]]
# (array([0.97659906, 0.85812357]), array([0.95281583, 0.92592593]), array([0.96456086, 0.89073634]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 64
# [[1257   57]
#  [  34  371]]
# (array([0.97366383, 0.86682243]), array([0.956621  , 0.91604938]), array([0.96506718, 0.8907563 ]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 65
# [[1254   60]
#  [  33  372]]
# (array([0.97435897, 0.86111111]), array([0.9543379 , 0.91851852]), array([0.96424452, 0.88888889]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 66
# [[1260   54]
#  [  33  372]]
# (array([0.97447796, 0.87323944]), array([0.95890411, 0.91851852]), array([0.96662831, 0.89530686]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 67
# [[1253   61]
#  [  33  372]]
# (array([0.97433904, 0.8591224 ]), array([0.95357686, 0.91851852]), array([0.96384615, 0.88782816]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 68
# [[1252   62]
#  [  30  375]]
# (array([0.97659906, 0.85812357]), array([0.95281583, 0.92592593]), array([0.96456086, 0.89073634]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 69
# [[1253   61]
#  [  37  368]]
# (array([0.97131783, 0.85780886]), array([0.95357686, 0.90864198]), array([0.96236559, 0.882494  ]), array([1314,  405]))
# Bons résultats 1621
# Erreurs: 98
# Avec max_depth= 70
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 71
# [[1261   53]
#  [  36  369]]
# (array([0.97224364, 0.87440758]), array([0.95966514, 0.91111111]), array([0.96591344, 0.8923821 ]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 72
# [[1256   58]
#  [  36  369]]
# (array([0.97213622, 0.86416862]), array([0.95585997, 0.91111111]), array([0.96392939, 0.88701923]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 73
# [[1252   62]
#  [  34  371]]
# (array([0.97356143, 0.85681293]), array([0.95281583, 0.91604938]), array([0.96307692, 0.88544153]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 74
# [[1252   62]
#  [  34  371]]
# (array([0.97356143, 0.85681293]), array([0.95281583, 0.91604938]), array([0.96307692, 0.88544153]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 75
# [[1258   56]
#  [  33  372]]
# (array([0.97443842, 0.86915888]), array([0.95738204, 0.91851852]), array([0.96583493, 0.89315726]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 76
# [[1263   51]
#  [  35  370]]
# (array([0.97303544, 0.87885986]), array([0.96118721, 0.91358025]), array([0.96707504, 0.89588378]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 77
# [[1263   51]
#  [  34  371]]
# (array([0.97378566, 0.87914692]), array([0.96118721, 0.91604938]), array([0.96744542, 0.89721886]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 78
# [[1259   55]
#  [  31  374]]
# (array([0.97596899, 0.87179487]), array([0.95814307, 0.92345679]), array([0.96697389, 0.89688249]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 79
# [[1258   56]
#  [  26  379]]
# (array([0.97975078, 0.87126437]), array([0.95738204, 0.93580247]), array([0.96843726, 0.90238095]), array([1314,  405]))
# Bons résultats 1637
# Erreurs: 82
# Avec max_depth= 80
# [[1254   60]
#  [  32  373]]
# (array([0.97511664, 0.86143187]), array([0.9543379 , 0.92098765]), array([0.96461538, 0.8902148 ]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 81
# [[1259   55]
#  [  33  372]]
# (array([0.9744582 , 0.87119438]), array([0.95814307, 0.91851852]), array([0.96623177, 0.89423077]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 82
# [[1259   55]
#  [  38  367]]
# (array([0.97070162, 0.86966825]), array([0.95814307, 0.90617284]), array([0.96438146, 0.88754534]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 83
# [[1262   52]
#  [  38  367]]
# (array([0.97076923, 0.87589499]), array([0.96042618, 0.90617284]), array([0.96557001, 0.8907767 ]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 84
# [[1262   52]
#  [  33  372]]
# (array([0.97451737, 0.87735849]), array([0.96042618, 0.91851852]), array([0.96742047, 0.89746683]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 85
# [[1260   54]
#  [  33  372]]
# (array([0.97447796, 0.87323944]), array([0.95890411, 0.91851852]), array([0.96662831, 0.89530686]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 86
# [[1254   60]
#  [  26  379]]
# (array([0.9796875 , 0.86332574]), array([0.9543379 , 0.93580247]), array([0.96684657, 0.89810427]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 87
# [[1259   55]
#  [  36  369]]
# (array([0.97220077, 0.87028302]), array([0.95814307, 0.91111111]), array([0.96512074, 0.89022919]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 88
# [[1257   57]
#  [  32  373]]
# (array([0.97517455, 0.86744186]), array([0.956621  , 0.92098765]), array([0.96580868, 0.89341317]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 89
# [[1259   55]
#  [  37  368]]
# (array([0.97145062, 0.86997636]), array([0.95814307, 0.90864198]), array([0.96475096, 0.88888889]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 90
# [[1263   51]
#  [  32  373]]
# (array([0.97528958, 0.87971698]), array([0.96118721, 0.92098765]), array([0.96818704, 0.89987937]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 91
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 92
# [[1257   57]
#  [  29  376]]
# (array([0.97744946, 0.86836028]), array([0.956621  , 0.92839506]), array([0.96692308, 0.8973747 ]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 93
# [[1253   61]
#  [  35  370]]
# (array([0.97282609, 0.85846868]), array([0.95357686, 0.91358025]), array([0.9631053 , 0.88516746]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 94
# [[1255   59]
#  [  33  372]]
# (array([0.97437888, 0.86310905]), array([0.95509893, 0.91851852]), array([0.96464258, 0.88995215]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 95
# [[1254   60]
#  [  30  375]]
# (array([0.97663551, 0.86206897]), array([0.9543379 , 0.92592593]), array([0.96535797, 0.89285714]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 96
# [[1265   49]
#  [  30  375]]
# (array([0.97683398, 0.88443396]), array([0.96270928, 0.92592593]), array([0.9697202 , 0.90470446]), array([1314,  405]))
# Bons résultats 1640
# Erreurs: 79
# Avec max_depth= 97
# [[1257   57]
#  [  37  368]]
# (array([0.97140649, 0.86588235]), array([0.956621  , 0.90864198]), array([0.96395706, 0.88674699]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 98
# [[1258   56]
#  [  34  371]]
# (array([0.97368421, 0.86885246]), array([0.95738204, 0.91604938]), array([0.96546431, 0.89182692]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 99
# [[1256   58]
#  [  37  368]]
# (array([0.97138438, 0.86384977]), array([0.95585997, 0.90864198]), array([0.96355965, 0.8856799 ]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95

# %% [markdown]
# Meilleur résultat obtenu :
# Avec max_depth= 96
# [[1265   49]
#  [  30  375]]
# (array([0.97683398, 0.88443396]), array([0.96270928, 0.92592593]), array([0.9697202 , 0.90470446]), array([1314,  405]))
# Bons résultats 1640
# Erreurs: 79

# %%
print("On teste min_samples_split:")
for i in range(1, 100):
  DT = tree.DecisionTreeClassifier(max_depth=i)
  DT = DT.fit(X_train, y_train)
  y_pred = DT.predict(X_test)
  matrice_confusion = confusion_matrix(y_test, y_pred)
  print("Avec max_depth=", i)
  print(matrice_confusion)
  stats = precision_recall_fscore_support(y_test, y_pred)
  print(stats)
  print('Bons résultats %d' % (y_test == y_pred).sum())
  print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# On teste min_samples_split:
# Avec max_depth= 1
# [[1314    0]
#  [ 405    0]]
# (array([0.76439791, 0.        ]), array([1., 0.]), array([0.86646884, 0.        ]), array([1314,  405]))
# Bons résultats 1314
# Erreurs: 405
# /home/alexane.jouglar/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Avec max_depth= 2
# [[1036  278]
#  [   1  404]]
# (array([0.99903568, 0.59237537]), array([0.78843227, 0.99753086]), array([0.88132709, 0.74333027]), array([1314,  405]))
# Bons résultats 1440
# Erreurs: 279
# Avec max_depth= 3
# [[1089  225]
#  [  11  394]]
# (array([0.99     , 0.6365105]), array([0.82876712, 0.97283951]), array([0.90223695, 0.76953125]), array([1314,  405]))
# Bons résultats 1483
# Erreurs: 236
# Avec max_depth= 4
# [[1229   85]
#  [ 132  273]]
# (array([0.90301249, 0.76256983]), array([0.93531202, 0.67407407]), array([0.9188785 , 0.71559633]), array([1314,  405]))
# Bons résultats 1502
# Erreurs: 217
# Avec max_depth= 5
# [[1133  181]
#  [   8  397]]
# (array([0.99298861, 0.68685121]), array([0.86225266, 0.98024691]), array([0.92301426, 0.80773143]), array([1314,  405]))
# Bons résultats 1530
# Erreurs: 189
# Avec max_depth= 6
# [[1184  130]
#  [  32  373]]
# (array([0.97368421, 0.7415507 ]), array([0.90106545, 0.92098765]), array([0.93596838, 0.8215859 ]), array([1314,  405]))
# Bons résultats 1557
# Erreurs: 162
# Avec max_depth= 7
# [[1201  113]
#  [  29  376]]
# (array([0.97642276, 0.76891616]), array([0.91400304, 0.92839506]), array([0.94418239, 0.84116331]), array([1314,  405]))
# Bons résultats 1577
# Erreurs: 142
# Avec max_depth= 8
# [[1209  105]
#  [  22  383]]
# (array([0.98212835, 0.78483607]), array([0.92009132, 0.94567901]), array([0.95009823, 0.85778275]), array([1314,  405]))
# Bons résultats 1592
# Erreurs: 127
# Avec max_depth= 9
# [[1224   90]
#  [  23  382]]
# (array([0.98155573, 0.80932203]), array([0.93150685, 0.94320988]), array([0.95587661, 0.87115165]), array([1314,  405]))
# Bons résultats 1606
# Erreurs: 113
# Avec max_depth= 10
# [[1226   88]
#  [  29  376]]
# (array([0.97689243, 0.81034483]), array([0.93302892, 0.92839506]), array([0.95445699, 0.86536249]), array([1314,  405]))
# Bons résultats 1602
# Erreurs: 117
# Avec max_depth= 11
# [[1233   81]
#  [  25  380]]
# (array([0.98012719, 0.82429501]), array([0.93835616, 0.9382716 ]), array([0.95878694, 0.87759815]), array([1314,  405]))
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth= 12
# [[1238   76]
#  [  27  378]]
# (array([0.97865613, 0.83259912]), array([0.94216134, 0.93333333]), array([0.96006204, 0.88009313]), array([1314,  405]))
# Bons résultats 1616
# Erreurs: 103
# Avec max_depth= 13
# [[1241   73]
#  [  26  379]]
# (array([0.97947908, 0.83849558]), array([0.94444444, 0.93580247]), array([0.96164277, 0.88448075]), array([1314,  405]))
# Bons résultats 1620
# Erreurs: 99
# Avec max_depth= 14
# [[1240   74]
#  [  28  377]]
# (array([0.97791798, 0.83592018]), array([0.94368341, 0.9308642 ]), array([0.96049574, 0.88084112]), array([1314,  405]))
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth= 15
# [[1238   76]
#  [  27  378]]
# (array([0.97865613, 0.83259912]), array([0.94216134, 0.93333333]), array([0.96006204, 0.88009313]), array([1314,  405]))
# Bons résultats 1616
# Erreurs: 103
# Avec max_depth= 16
# [[1251   63]
#  [  29  376]]
# (array([0.97734375, 0.85649203]), array([0.95205479, 0.92839506]), array([0.96453354, 0.89099526]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 17
# [[1239   75]
#  [  28  377]]
# (array([0.97790055, 0.8340708 ]), array([0.94292237, 0.9308642 ]), array([0.96009299, 0.8798133 ]), array([1314,  405]))
# Bons résultats 1616
# Erreurs: 103
# Avec max_depth= 18
# [[1251   63]
#  [  22  383]]
# (array([0.98271799, 0.85874439]), array([0.95205479, 0.94567901]), array([0.96714341, 0.90011751]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 19
# [[1251   63]
#  [  31  374]]
# (array([0.97581903, 0.85583524]), array([0.95205479, 0.92345679]), array([0.96379045, 0.88836105]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 20
# [[1251   63]
#  [  29  376]]
# (array([0.97734375, 0.85649203]), array([0.95205479, 0.92839506]), array([0.96453354, 0.89099526]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 21
# [[1252   62]
#  [  32  373]]
# (array([0.97507788, 0.85747126]), array([0.95281583, 0.92098765]), array([0.96381832, 0.88809524]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 22
# [[1256   58]
#  [  32  373]]
# (array([0.97515528, 0.86542923]), array([0.95585997, 0.92098765]), array([0.96541122, 0.8923445 ]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 23
# [[1253   61]
#  [  29  376]]
# (array([0.9773791, 0.8604119]), array([0.95357686, 0.92839506]), array([0.96533128, 0.89311164]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 24
# [[1248   66]
#  [  28  377]]
# (array([0.97805643, 0.8510158 ]), array([0.94977169, 0.9308642 ]), array([0.96370656, 0.88915094]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 25
# [[1251   63]
#  [  29  376]]
# (array([0.97734375, 0.85649203]), array([0.95205479, 0.92839506]), array([0.96453354, 0.89099526]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 26
# [[1253   61]
#  [  29  376]]
# (array([0.9773791, 0.8604119]), array([0.95357686, 0.92839506]), array([0.96533128, 0.89311164]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 27
# [[1258   56]
#  [  33  372]]
# (array([0.97443842, 0.86915888]), array([0.95738204, 0.91851852]), array([0.96583493, 0.89315726]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 28
# [[1252   62]
#  [  35  370]]
# (array([0.97280497, 0.85648148]), array([0.95281583, 0.91358025]), array([0.96270665, 0.88410992]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 29
# [[1253   61]
#  [  32  373]]
# (array([0.97509728, 0.859447  ]), array([0.95357686, 0.92098765]), array([0.96421701, 0.88915375]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 30
# [[1259   55]
#  [  37  368]]
# (array([0.97145062, 0.86997636]), array([0.95814307, 0.90864198]), array([0.96475096, 0.88888889]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 31
# [[1259   55]
#  [  33  372]]
# (array([0.9744582 , 0.87119438]), array([0.95814307, 0.91851852]), array([0.96623177, 0.89423077]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 32
# [[1255   59]
#  [  33  372]]
# (array([0.97437888, 0.86310905]), array([0.95509893, 0.91851852]), array([0.96464258, 0.88995215]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 33
# [[1257   57]
#  [  37  368]]
# (array([0.97140649, 0.86588235]), array([0.956621  , 0.90864198]), array([0.96395706, 0.88674699]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 34
# [[1256   58]
#  [  32  373]]
# (array([0.97515528, 0.86542923]), array([0.95585997, 0.92098765]), array([0.96541122, 0.8923445 ]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 35
# [[1250   64]
#  [  31  374]]
# (array([0.97580016, 0.85388128]), array([0.95129376, 0.92345679]), array([0.96339114, 0.88730724]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 36
# [[1258   56]
#  [  31  374]]
# (array([0.97595035, 0.86976744]), array([0.95738204, 0.92345679]), array([0.96657703, 0.89580838]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 37
# [[1259   55]
#  [  30  375]]
# (array([0.97672614, 0.87209302]), array([0.95814307, 0.92592593]), array([0.96734537, 0.89820359]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 38
# [[1254   60]
#  [  30  375]]
# (array([0.97663551, 0.86206897]), array([0.9543379 , 0.92592593]), array([0.96535797, 0.89285714]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 39
# [[1256   58]
#  [  34  371]]
# (array([0.97364341, 0.86480186]), array([0.95585997, 0.91604938]), array([0.96466974, 0.88968825]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 40
# [[1248   66]
#  [  34  371]]
# (array([0.97347894, 0.84897025]), array([0.94977169, 0.91604938]), array([0.9614792 , 0.88123515]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 41
# [[1259   55]
#  [  37  368]]
# (array([0.97145062, 0.86997636]), array([0.95814307, 0.90864198]), array([0.96475096, 0.88888889]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 42
# [[1258   56]
#  [  29  376]]
# (array([0.97746698, 0.87037037]), array([0.95738204, 0.92839506]), array([0.96732026, 0.89844683]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 43
# [[1259   55]
#  [  35  370]]
# (array([0.97295209, 0.87058824]), array([0.95814307, 0.91358025]), array([0.9654908 , 0.89156627]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 44
# [[1253   61]
#  [  32  373]]
# (array([0.97509728, 0.859447  ]), array([0.95357686, 0.92098765]), array([0.96421701, 0.88915375]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 45
# [[1258   56]
#  [  30  375]]
# (array([0.97670807, 0.87006961]), array([0.95738204, 0.92592593]), array([0.9669485 , 0.89712919]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 46
# [[1254   60]
#  [  31  374]]
# (array([0.97587549, 0.86175115]), array([0.9543379 , 0.92345679]), array([0.96498653, 0.89153754]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 47
# [[1259   55]
#  [  33  372]]
# (array([0.9744582 , 0.87119438]), array([0.95814307, 0.91851852]), array([0.96623177, 0.89423077]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 48
# [[1260   54]
#  [  32  373]]
# (array([0.9752322, 0.8735363]), array([0.95890411, 0.92098765]), array([0.96699923, 0.89663462]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 49
# [[1262   52]
#  [  31  374]]
# (array([0.97602475, 0.87793427]), array([0.96042618, 0.92345679]), array([0.96816264, 0.90012034]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 50
# [[1257   57]
#  [  32  373]]
# (array([0.97517455, 0.86744186]), array([0.956621  , 0.92098765]), array([0.96580868, 0.89341317]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 51
# [[1257   57]
#  [  37  368]]
# (array([0.97140649, 0.86588235]), array([0.956621  , 0.90864198]), array([0.96395706, 0.88674699]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 52
# [[1256   58]
#  [  31  374]]
# (array([0.97591298, 0.86574074]), array([0.95585997, 0.92345679]), array([0.96578239, 0.89366786]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 53
# [[1251   63]
#  [  33  372]]
# (array([0.97429907, 0.85517241]), array([0.95205479, 0.91851852]), array([0.9630485 , 0.88571429]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 54
# [[1251   63]
#  [  29  376]]
# (array([0.97734375, 0.85649203]), array([0.95205479, 0.92839506]), array([0.96453354, 0.89099526]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 55
# [[1256   58]
#  [  34  371]]
# (array([0.97364341, 0.86480186]), array([0.95585997, 0.91604938]), array([0.96466974, 0.88968825]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 56
# [[1251   63]
#  [  30  375]]
# (array([0.9765808 , 0.85616438]), array([0.95205479, 0.92592593]), array([0.96416185, 0.88967972]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 57
# [[1259   55]
#  [  35  370]]
# (array([0.97295209, 0.87058824]), array([0.95814307, 0.91358025]), array([0.9654908 , 0.89156627]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 58
# [[1257   57]
#  [  37  368]]
# (array([0.97140649, 0.86588235]), array([0.956621  , 0.90864198]), array([0.96395706, 0.88674699]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 59
# [[1260   54]
#  [  39  366]]
# (array([0.96997691, 0.87142857]), array([0.95890411, 0.9037037 ]), array([0.96440873, 0.88727273]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 60
# [[1254   60]
#  [  32  373]]
# (array([0.97511664, 0.86143187]), array([0.9543379 , 0.92098765]), array([0.96461538, 0.8902148 ]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 61
# [[1255   59]
#  [  27  378]]
# (array([0.97893916, 0.86498856]), array([0.95509893, 0.93333333]), array([0.96687211, 0.89786223]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 62
# [[1261   53]
#  [  31  374]]
# (array([0.97600619, 0.87587822]), array([0.95966514, 0.92345679]), array([0.96776669, 0.89903846]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 63
# [[1251   63]
#  [  34  371]]
# (array([0.97354086, 0.85483871]), array([0.95205479, 0.91604938]), array([0.96267795, 0.88438617]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 64
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 65
# [[1258   56]
#  [  39  366]]
# (array([0.96993061, 0.86729858]), array([0.95738204, 0.9037037 ]), array([0.96361547, 0.88512696]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 66
# [[1259   55]
#  [  36  369]]
# (array([0.97220077, 0.87028302]), array([0.95814307, 0.91111111]), array([0.96512074, 0.89022919]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 67
# [[1251   63]
#  [  37  368]]
# (array([0.97127329, 0.85382831]), array([0.95205479, 0.90864198]), array([0.96156802, 0.88038278]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 68
# [[1256   58]
#  [  31  374]]
# (array([0.97591298, 0.86574074]), array([0.95585997, 0.92345679]), array([0.96578239, 0.89366786]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 69
# [[1261   53]
#  [  32  373]]
# (array([0.97525135, 0.87558685]), array([0.95966514, 0.92098765]), array([0.96739547, 0.8977136 ]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 70
# [[1252   62]
#  [  27  378]]
# (array([0.97888976, 0.85909091]), array([0.95281583, 0.93333333]), array([0.96567682, 0.89467456]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 71
# [[1255   59]
#  [  35  370]]
# (array([0.97286822, 0.86247086]), array([0.95509893, 0.91358025]), array([0.96390169, 0.88729017]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 72
# [[1254   60]
#  [  31  374]]
# (array([0.97587549, 0.86175115]), array([0.9543379 , 0.92345679]), array([0.96498653, 0.89153754]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 73
# [[1256   58]
#  [  29  376]]
# (array([0.97743191, 0.86635945]), array([0.95585997, 0.92839506]), array([0.96652559, 0.89630513]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 74
# [[1257   57]
#  [  33  372]]
# (array([0.9744186 , 0.86713287]), array([0.956621  , 0.91851852]), array([0.96543779, 0.89208633]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 75
# [[1249   65]
#  [  28  377]]
# (array([0.97807361, 0.85294118]), array([0.95053272, 0.9308642 ]), array([0.96410652, 0.89020071]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 76
# [[1255   59]
#  [  29  376]]
# (array([0.97741433, 0.86436782]), array([0.95509893, 0.92839506]), array([0.96612779, 0.8952381 ]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 77
# [[1259   55]
#  [  32  373]]
# (array([0.97521301, 0.87149533]), array([0.95814307, 0.92098765]), array([0.96660269, 0.89555822]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 78
# [[1257   57]
#  [  32  373]]
# (array([0.97517455, 0.86744186]), array([0.956621  , 0.92098765]), array([0.96580868, 0.89341317]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 79
# [[1253   61]
#  [  32  373]]
# (array([0.97509728, 0.859447  ]), array([0.95357686, 0.92098765]), array([0.96421701, 0.88915375]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 80
# [[1254   60]
#  [  34  371]]
# (array([0.97360248, 0.86078886]), array([0.9543379 , 0.91604938]), array([0.96387394, 0.88755981]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 81
# [[1256   58]
#  [  30  375]]
# (array([0.97667185, 0.86605081]), array([0.95585997, 0.92592593]), array([0.96615385, 0.89498807]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 82
# [[1257   57]
#  [  32  373]]
# (array([0.97517455, 0.86744186]), array([0.956621  , 0.92098765]), array([0.96580868, 0.89341317]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 83
# [[1265   49]
#  [  36  369]]
# (array([0.97232898, 0.88277512]), array([0.96270928, 0.91111111]), array([0.96749522, 0.89671932]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 84
# [[1249   65]
#  [  32  373]]
# (array([0.97501952, 0.85159817]), array([0.95053272, 0.92098765]), array([0.96262042, 0.88493476]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 85
# [[1253   61]
#  [  27  378]]
# (array([0.97890625, 0.86104784]), array([0.95357686, 0.93333333]), array([0.96607556, 0.8957346 ]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 86
# [[1256   58]
#  [  35  370]]
# (array([0.97288923, 0.86448598]), array([0.95585997, 0.91358025]), array([0.96429942, 0.88835534]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 87
# [[1259   55]
#  [  33  372]]
# (array([0.9744582 , 0.87119438]), array([0.95814307, 0.91851852]), array([0.96623177, 0.89423077]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 88
# [[1254   60]
#  [  33  372]]
# (array([0.97435897, 0.86111111]), array([0.9543379 , 0.91851852]), array([0.96424452, 0.88888889]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 89
# [[1259   55]
#  [  32  373]]
# (array([0.97521301, 0.87149533]), array([0.95814307, 0.92098765]), array([0.96660269, 0.89555822]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 90
# [[1254   60]
#  [  35  370]]
# (array([0.97284717, 0.86046512]), array([0.9543379 , 0.91358025]), array([0.96350365, 0.88622754]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 91
# [[1254   60]
#  [  26  379]]
# (array([0.9796875 , 0.86332574]), array([0.9543379 , 0.93580247]), array([0.96684657, 0.89810427]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 92
# [[1256   58]
#  [  32  373]]
# (array([0.97515528, 0.86542923]), array([0.95585997, 0.92098765]), array([0.96541122, 0.8923445 ]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 93
# [[1248   66]
#  [  31  374]]
# (array([0.97576231, 0.85      ]), array([0.94977169, 0.92345679]), array([0.96259159, 0.8852071 ]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 94
# [[1261   53]
#  [  31  374]]
# (array([0.97600619, 0.87587822]), array([0.95966514, 0.92345679]), array([0.96776669, 0.89903846]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 95
# [[1252   62]
#  [  30  375]]
# (array([0.97659906, 0.85812357]), array([0.95281583, 0.92592593]), array([0.96456086, 0.89073634]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 96
# [[1251   63]
#  [  33  372]]
# (array([0.97429907, 0.85517241]), array([0.95205479, 0.91851852]), array([0.9630485 , 0.88571429]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 97
# [[1260   54]
#  [  32  373]]
# (array([0.9752322, 0.8735363]), array([0.95890411, 0.92098765]), array([0.96699923, 0.89663462]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 98
# [[1253   61]
#  [  36  369]]
# (array([0.97207137, 0.85813953]), array([0.95357686, 0.91111111]), array([0.96273531, 0.88383234]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 99
# [[1262   52]
#  [  39  366]]
# (array([0.97002306, 0.87559809]), array([0.96042618, 0.9037037 ]), array([0.96520076, 0.88942892]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91

# %%
print("On teste min_samples_leaf:")
for i in range(1, 100):
  DT = tree.DecisionTreeClassifier(max_depth=i)
  DT = DT.fit(X_train, y_train)
  y_pred = DT.predict(X_test)
  matrice_confusion = confusion_matrix(y_test, y_pred)
  print("Avec max_depth=", i)
  print(matrice_confusion)
  stats = precision_recall_fscore_support(y_test, y_pred)
  print(stats)
  print('Bons résultats %d' % (y_test == y_pred).sum())
  print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# On teste min_samples_leaf:
# Avec max_depth= 1
# [[1314    0]
#  [ 405    0]]
# (array([0.76439791, 0.        ]), array([1., 0.]), array([0.86646884, 0.        ]), array([1314,  405]))
# Bons résultats 1314
# Erreurs: 405
# /home/alexane.jouglar/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Avec max_depth= 2
# [[1036  278]
#  [   1  404]]
# (array([0.99903568, 0.59237537]), array([0.78843227, 0.99753086]), array([0.88132709, 0.74333027]), array([1314,  405]))
# Bons résultats 1440
# Erreurs: 279
# Avec max_depth= 3
# [[1089  225]
#  [  11  394]]
# (array([0.99     , 0.6365105]), array([0.82876712, 0.97283951]), array([0.90223695, 0.76953125]), array([1314,  405]))
# Bons résultats 1483
# Erreurs: 236
# Avec max_depth= 4
# [[1229   85]
#  [ 132  273]]
# (array([0.90301249, 0.76256983]), array([0.93531202, 0.67407407]), array([0.9188785 , 0.71559633]), array([1314,  405]))
# Bons résultats 1502
# Erreurs: 217
# Avec max_depth= 5
# [[1133  181]
#  [   6  399]]
# (array([0.99473222, 0.68793103]), array([0.86225266, 0.98518519]), array([0.92376682, 0.81015228]), array([1314,  405]))
# Bons résultats 1532
# Erreurs: 187
# Avec max_depth= 6
# [[1184  130]
#  [  30  375]]
# (array([0.9752883 , 0.74257426]), array([0.90106545, 0.92592593]), array([0.93670886, 0.82417582]), array([1314,  405]))
# Bons résultats 1559
# Erreurs: 160
# Avec max_depth= 7
# [[1201  113]
#  [  27  378]]
# (array([0.97801303, 0.76985743]), array([0.91400304, 0.93333333]), array([0.94492526, 0.84375   ]), array([1314,  405]))
# Bons résultats 1579
# Erreurs: 140
# Avec max_depth= 8
# [[1210  104]
#  [  27  378]]
# (array([0.978173  , 0.78423237]), array([0.92085236, 0.93333333]), array([0.94864759, 0.85231116]), array([1314,  405]))
# Bons résultats 1588
# Erreurs: 131
# Avec max_depth= 9
# [[1218   96]
#  [  24  381]]
# (array([0.98067633, 0.79874214]), array([0.92694064, 0.94074074]), array([0.95305164, 0.86394558]), array([1314,  405]))
# Bons résultats 1599
# Erreurs: 120
# Avec max_depth= 10
# [[1227   87]
#  [  30  375]]
# (array([0.97613365, 0.81168831]), array([0.93378995, 0.92592593]), array([0.95449242, 0.8650519 ]), array([1314,  405]))
# Bons résultats 1602
# Erreurs: 117
# Avec max_depth= 11
# [[1232   82]
#  [  27  378]]
# (array([0.97855441, 0.82173913]), array([0.93759513, 0.93333333]), array([0.957637  , 0.87398844]), array([1314,  405]))
# Bons résultats 1610
# Erreurs: 109
# Avec max_depth= 12
# [[1243   71]
#  [  29  376]]
# (array([0.97720126, 0.84116331]), array([0.94596651, 0.92839506]), array([0.96133024, 0.88262911]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 13
# [[1235   79]
#  [  27  378]]
# (array([0.97860539, 0.82713348]), array([0.93987823, 0.93333333]), array([0.95885093, 0.87703016]), array([1314,  405]))
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth= 14
# [[1241   73]
#  [  30  375]]
# (array([0.97639654, 0.83705357]), array([0.94444444, 0.92592593]), array([0.96015474, 0.87924971]), array([1314,  405]))
# Bons résultats 1616
# Erreurs: 103
# Avec max_depth= 15
# [[1248   66]
#  [  30  375]]
# (array([0.97652582, 0.85034014]), array([0.94977169, 0.92592593]), array([0.96296296, 0.88652482]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 16
# [[1245   69]
#  [  28  377]]
# (array([0.97800471, 0.84529148]), array([0.94748858, 0.9308642 ]), array([0.96250483, 0.88601645]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 17
# [[1240   74]
#  [  31  374]]
# (array([0.97560976, 0.83482143]), array([0.94368341, 0.92345679]), array([0.95938104, 0.87690504]), array([1314,  405]))
# Bons résultats 1614
# Erreurs: 105
# Avec max_depth= 18
# [[1253   61]
#  [  31  374]]
# (array([0.9758567 , 0.85977011]), array([0.95357686, 0.92345679]), array([0.96458814, 0.89047619]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 19
# [[1254   60]
#  [  32  373]]
# (array([0.97511664, 0.86143187]), array([0.9543379 , 0.92098765]), array([0.96461538, 0.8902148 ]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 20
# [[1256   58]
#  [  30  375]]
# (array([0.97667185, 0.86605081]), array([0.95585997, 0.92592593]), array([0.96615385, 0.89498807]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 21
# [[1250   64]
#  [  30  375]]
# (array([0.9765625 , 0.85421412]), array([0.95129376, 0.92592593]), array([0.96376253, 0.88862559]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 22
# [[1257   57]
#  [  27  378]]
# (array([0.97897196, 0.86896552]), array([0.956621  , 0.93333333]), array([0.96766744, 0.9       ]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 23
# [[1255   59]
#  [  35  370]]
# (array([0.97286822, 0.86247086]), array([0.95509893, 0.91358025]), array([0.96390169, 0.88729017]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 24
# [[1260   54]
#  [  32  373]]
# (array([0.9752322, 0.8735363]), array([0.95890411, 0.92098765]), array([0.96699923, 0.89663462]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 25
# [[1249   65]
#  [  28  377]]
# (array([0.97807361, 0.85294118]), array([0.95053272, 0.9308642 ]), array([0.96410652, 0.89020071]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 26
# [[1250   64]
#  [  25  380]]
# (array([0.98039216, 0.85585586]), array([0.95129376, 0.9382716 ]), array([0.96562379, 0.89517079]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 27
# [[1259   55]
#  [  31  374]]
# (array([0.97596899, 0.87179487]), array([0.95814307, 0.92345679]), array([0.96697389, 0.89688249]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 28
# [[1258   56]
#  [  41  364]]
# (array([0.96843726, 0.86666667]), array([0.95738204, 0.89876543]), array([0.96287792, 0.88242424]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 29
# [[1255   59]
#  [  39  366]]
# (array([0.9698609 , 0.86117647]), array([0.95509893, 0.9037037 ]), array([0.96242331, 0.88192771]), array([1314,  405]))
# Bons résultats 1621
# Erreurs: 98
# Avec max_depth= 30
# [[1249   65]
#  [  29  376]]
# (array([0.97730829, 0.85260771]), array([0.95053272, 0.92839506]), array([0.96373457, 0.88888889]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 31
# [[1252   62]
#  [  32  373]]
# (array([0.97507788, 0.85747126]), array([0.95281583, 0.92098765]), array([0.96381832, 0.88809524]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 32
# [[1248   66]
#  [  30  375]]
# (array([0.97652582, 0.85034014]), array([0.94977169, 0.92592593]), array([0.96296296, 0.88652482]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 33
# [[1257   57]
#  [  30  375]]
# (array([0.97668998, 0.86805556]), array([0.956621  , 0.92592593]), array([0.96655133, 0.89605735]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 34
# [[1256   58]
#  [  38  367]]
# (array([0.97063369, 0.86352941]), array([0.95585997, 0.90617284]), array([0.96319018, 0.88433735]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 35
# [[1255   59]
#  [  38  367]]
# (array([0.97061098, 0.86150235]), array([0.95509893, 0.90617284]), array([0.96279248, 0.88327316]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 36
# [[1255   59]
#  [  38  367]]
# (array([0.97061098, 0.86150235]), array([0.95509893, 0.90617284]), array([0.96279248, 0.88327316]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 37
# [[1255   59]
#  [  37  368]]
# (array([0.97136223, 0.8618267 ]), array([0.95509893, 0.90864198]), array([0.96316193, 0.88461538]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 38
# [[1257   57]
#  [  32  373]]
# (array([0.97517455, 0.86744186]), array([0.956621  , 0.92098765]), array([0.96580868, 0.89341317]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 39
# [[1260   54]
#  [  34  371]]
# (array([0.97372488, 0.87294118]), array([0.95890411, 0.91604938]), array([0.96625767, 0.8939759 ]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 40
# [[1249   65]
#  [  34  371]]
# (array([0.97349961, 0.85091743]), array([0.95053272, 0.91604938]), array([0.96187909, 0.882283  ]), array([1314,  405]))
# Bons résultats 1620
# Erreurs: 99
# Avec max_depth= 41
# [[1259   55]
#  [  32  373]]
# (array([0.97521301, 0.87149533]), array([0.95814307, 0.92098765]), array([0.96660269, 0.89555822]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 42
# [[1257   57]
#  [  33  372]]
# (array([0.9744186 , 0.86713287]), array([0.956621  , 0.91851852]), array([0.96543779, 0.89208633]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 43
# [[1252   62]
#  [  27  378]]
# (array([0.97888976, 0.85909091]), array([0.95281583, 0.93333333]), array([0.96567682, 0.89467456]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 44
# [[1248   66]
#  [  29  376]]
# (array([0.97729052, 0.85067873]), array([0.94977169, 0.92839506]), array([0.96333462, 0.88783943]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 45
# [[1247   67]
#  [  33  372]]
# (array([0.97421875, 0.84738041]), array([0.94901065, 0.91851852]), array([0.9614495 , 0.88151659]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 46
# [[1255   59]
#  [  37  368]]
# (array([0.97136223, 0.8618267 ]), array([0.95509893, 0.90864198]), array([0.96316193, 0.88461538]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 47
# [[1252   62]
#  [  29  376]]
# (array([0.97736144, 0.85844749]), array([0.95281583, 0.92839506]), array([0.96493256, 0.89205219]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 48
# [[1254   60]
#  [  37  368]]
# (array([0.97134005, 0.85981308]), array([0.9543379 , 0.90864198]), array([0.96276392, 0.88355342]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 49
# [[1259   55]
#  [  28  377]]
# (array([0.97824398, 0.87268519]), array([0.95814307, 0.9308642 ]), array([0.9680892 , 0.90083632]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 50
# [[1254   60]
#  [  31  374]]
# (array([0.97587549, 0.86175115]), array([0.9543379 , 0.92345679]), array([0.96498653, 0.89153754]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 51
# [[1259   55]
#  [  31  374]]
# (array([0.97596899, 0.87179487]), array([0.95814307, 0.92345679]), array([0.96697389, 0.89688249]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 52
# [[1251   63]
#  [  29  376]]
# (array([0.97734375, 0.85649203]), array([0.95205479, 0.92839506]), array([0.96453354, 0.89099526]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 53
# [[1251   63]
#  [  37  368]]
# (array([0.97127329, 0.85382831]), array([0.95205479, 0.90864198]), array([0.96156802, 0.88038278]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 54
# [[1258   56]
#  [  33  372]]
# (array([0.97443842, 0.86915888]), array([0.95738204, 0.91851852]), array([0.96583493, 0.89315726]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 55
# [[1260   54]
#  [  31  374]]
# (array([0.97598761, 0.87383178]), array([0.95890411, 0.92345679]), array([0.96737044, 0.89795918]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 56
# [[1264   50]
#  [  36  369]]
# (array([0.97230769, 0.88066826]), array([0.96194825, 0.91111111]), array([0.96710023, 0.89563107]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 57
# [[1255   59]
#  [  28  377]]
# (array([0.97817615, 0.8646789 ]), array([0.95509893, 0.9308642 ]), array([0.96649981, 0.89655172]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 58
# [[1255   59]
#  [  31  374]]
# (array([0.97589425, 0.86374134]), array([0.95509893, 0.92345679]), array([0.96538462, 0.89260143]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 59
# [[1255   59]
#  [  32  373]]
# (array([0.97513598, 0.86342593]), array([0.95509893, 0.92098765]), array([0.96501346, 0.89127838]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 60
# [[1261   53]
#  [  31  374]]
# (array([0.97600619, 0.87587822]), array([0.95966514, 0.92345679]), array([0.96776669, 0.89903846]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 61
# [[1265   49]
#  [  42  363]]
# (array([0.96786534, 0.88106796]), array([0.96270928, 0.8962963 ]), array([0.96528043, 0.88861689]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 62
# [[1251   63]
#  [  33  372]]
# (array([0.97429907, 0.85517241]), array([0.95205479, 0.91851852]), array([0.9630485 , 0.88571429]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 63
# [[1262   52]
#  [  28  377]]
# (array([0.97829457, 0.87878788]), array([0.96042618, 0.9308642 ]), array([0.96927803, 0.90407674]), array([1314,  405]))
# Bons résultats 1639
# Erreurs: 80
# Avec max_depth= 64
# [[1259   55]
#  [  37  368]]
# (array([0.97145062, 0.86997636]), array([0.95814307, 0.90864198]), array([0.96475096, 0.88888889]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 65
# [[1258   56]
#  [  41  364]]
# (array([0.96843726, 0.86666667]), array([0.95738204, 0.89876543]), array([0.96287792, 0.88242424]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 66
# [[1257   57]
#  [  27  378]]
# (array([0.97897196, 0.86896552]), array([0.956621  , 0.93333333]), array([0.96766744, 0.9       ]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 67
# [[1253   61]
#  [  37  368]]
# (array([0.97131783, 0.85780886]), array([0.95357686, 0.90864198]), array([0.96236559, 0.882494  ]), array([1314,  405]))
# Bons résultats 1621
# Erreurs: 98
# Avec max_depth= 68
# [[1249   65]
#  [  30  375]]
# (array([0.97654418, 0.85227273]), array([0.95053272, 0.92592593]), array([0.9633629 , 0.88757396]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 69
# [[1251   63]
#  [  33  372]]
# (array([0.97429907, 0.85517241]), array([0.95205479, 0.91851852]), array([0.9630485 , 0.88571429]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 70
# [[1256   58]
#  [  32  373]]
# (array([0.97515528, 0.86542923]), array([0.95585997, 0.92098765]), array([0.96541122, 0.8923445 ]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 71
# [[1255   59]
#  [  33  372]]
# (array([0.97437888, 0.86310905]), array([0.95509893, 0.91851852]), array([0.96464258, 0.88995215]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 72
# [[1256   58]
#  [  31  374]]
# (array([0.97591298, 0.86574074]), array([0.95585997, 0.92345679]), array([0.96578239, 0.89366786]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 73
# [[1251   63]
#  [  33  372]]
# (array([0.97429907, 0.85517241]), array([0.95205479, 0.91851852]), array([0.9630485 , 0.88571429]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 74
# [[1256   58]
#  [  33  372]]
# (array([0.97439876, 0.86511628]), array([0.95585997, 0.91851852]), array([0.96504034, 0.89101796]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 75
# [[1256   58]
#  [  39  366]]
# (array([0.96988417, 0.86320755]), array([0.95585997, 0.9037037 ]), array([0.962821  , 0.88299156]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 76
# [[1252   62]
#  [  35  370]]
# (array([0.97280497, 0.85648148]), array([0.95281583, 0.91358025]), array([0.96270665, 0.88410992]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 77
# [[1250   64]
#  [  33  372]]
# (array([0.97427903, 0.85321101]), array([0.95129376, 0.91851852]), array([0.96264921, 0.88466112]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 78
# [[1263   51]
#  [  33  372]]
# (array([0.97453704, 0.87943262]), array([0.96118721, 0.91851852]), array([0.96781609, 0.89855072]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 79
# [[1255   59]
#  [  36  369]]
# (array([0.97211464, 0.86214953]), array([0.95509893, 0.91111111]), array([0.96353167, 0.88595438]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 80
# [[1252   62]
#  [  31  374]]
# (array([0.97583788, 0.85779817]), array([0.95281583, 0.92345679]), array([0.96418945, 0.88941736]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 81
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 82
# [[1257   57]
#  [  32  373]]
# (array([0.97517455, 0.86744186]), array([0.956621  , 0.92098765]), array([0.96580868, 0.89341317]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 83
# [[1256   58]
#  [  30  375]]
# (array([0.97667185, 0.86605081]), array([0.95585997, 0.92592593]), array([0.96615385, 0.89498807]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 84
# [[1247   67]
#  [  30  375]]
# (array([0.97650744, 0.84841629]), array([0.94901065, 0.92592593]), array([0.96256272, 0.88547816]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 85
# [[1252   62]
#  [  34  371]]
# (array([0.97356143, 0.85681293]), array([0.95281583, 0.91604938]), array([0.96307692, 0.88544153]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 86
# [[1259   55]
#  [  36  369]]
# (array([0.97220077, 0.87028302]), array([0.95814307, 0.91111111]), array([0.96512074, 0.89022919]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 87
# [[1259   55]
#  [  27  378]]
# (array([0.97900467, 0.87297921]), array([0.95814307, 0.93333333]), array([0.96846154, 0.90214797]), array([1314,  405]))
# Bons résultats 1637
# Erreurs: 82
# Avec max_depth= 88
# [[1252   62]
#  [  31  374]]
# (array([0.97583788, 0.85779817]), array([0.95281583, 0.92345679]), array([0.96418945, 0.88941736]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 89
# [[1256   58]
#  [  31  374]]
# (array([0.97591298, 0.86574074]), array([0.95585997, 0.92345679]), array([0.96578239, 0.89366786]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 90
# [[1251   63]
#  [  28  377]]
# (array([0.9781079 , 0.85681818]), array([0.95205479, 0.9308642 ]), array([0.96490551, 0.89230769]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 91
# [[1255   59]
#  [  36  369]]
# (array([0.97211464, 0.86214953]), array([0.95509893, 0.91111111]), array([0.96353167, 0.88595438]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 92
# [[1252   62]
#  [  29  376]]
# (array([0.97736144, 0.85844749]), array([0.95281583, 0.92839506]), array([0.96493256, 0.89205219]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 93
# [[1250   64]
#  [  31  374]]
# (array([0.97580016, 0.85388128]), array([0.95129376, 0.92345679]), array([0.96339114, 0.88730724]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 94
# [[1259   55]
#  [  36  369]]
# (array([0.97220077, 0.87028302]), array([0.95814307, 0.91111111]), array([0.96512074, 0.89022919]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 95
# [[1264   50]
#  [  37  368]]
# (array([0.97156034, 0.88038278]), array([0.96194825, 0.90864198]), array([0.9667304 , 0.89428919]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 96
# [[1254   60]
#  [  29  376]]
# (array([0.97739673, 0.86238532]), array([0.9543379 , 0.92839506]), array([0.96572969, 0.8941736 ]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 97
# [[1254   60]
#  [  35  370]]
# (array([0.97284717, 0.86046512]), array([0.9543379 , 0.91358025]), array([0.96350365, 0.88622754]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 98
# [[1261   53]
#  [  34  371]]
# (array([0.97374517, 0.875     ]), array([0.95966514, 0.91604938]), array([0.96665389, 0.89505428]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 99
# [[1263   51]
#  [  32  373]]
# (array([0.97528958, 0.87971698]), array([0.96118721, 0.92098765]), array([0.96818704, 0.89987937]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83

# %%
print("On teste max_features:")
for i in range(1, 100):
  DT = tree.DecisionTreeClassifier(max_depth=i)
  DT = DT.fit(X_train, y_train)
  y_pred = DT.predict(X_test)
  matrice_confusion = confusion_matrix(y_test, y_pred)
  print("Avec max_depth=", i)
  print(matrice_confusion)
  stats = precision_recall_fscore_support(y_test, y_pred)
  print(stats)
  print('Bons résultats %d' % (y_test == y_pred).sum())
  print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# On teste max_features:
# Avec max_depth= 1
# [[1314    0]
#  [ 405    0]]
# (array([0.76439791, 0.        ]), array([1., 0.]), array([0.86646884, 0.        ]), array([1314,  405]))
# Bons résultats 1314
# Erreurs: 405
# /home/alexane.jouglar/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Avec max_depth= 2
# [[1036  278]
#  [   1  404]]
# (array([0.99903568, 0.59237537]), array([0.78843227, 0.99753086]), array([0.88132709, 0.74333027]), array([1314,  405]))
# Bons résultats 1440
# Erreurs: 279
# Avec max_depth= 3
# [[1089  225]
#  [  11  394]]
# (array([0.99     , 0.6365105]), array([0.82876712, 0.97283951]), array([0.90223695, 0.76953125]), array([1314,  405]))
# Bons résultats 1483
# Erreurs: 236
# Avec max_depth= 4
# [[1229   85]
#  [ 132  273]]
# (array([0.90301249, 0.76256983]), array([0.93531202, 0.67407407]), array([0.9188785 , 0.71559633]), array([1314,  405]))
# Bons résultats 1502
# Erreurs: 217
# Avec max_depth= 5
# [[1133  181]
#  [   5  400]]
# (array([0.99560633, 0.68846816]), array([0.86225266, 0.98765432]), array([0.92414356, 0.81135903]), array([1314,  405]))
# Bons résultats 1533
# Erreurs: 186
# Avec max_depth= 6
# [[1184  130]
#  [  34  371]]
# (array([0.97208539, 0.74051896]), array([0.90106545, 0.91604938]), array([0.93522907, 0.81898455]), array([1314,  405]))
# Bons résultats 1555
# Erreurs: 164
# Avec max_depth= 7
# [[1200  114]
#  [  28  377]]
# (array([0.9771987 , 0.76782077]), array([0.91324201, 0.9308642 ]), array([0.94413847, 0.84151786]), array([1314,  405]))
# Bons résultats 1577
# Erreurs: 142
# Avec max_depth= 8
# [[1212  102]
#  [  25  380]]
# (array([0.97978981, 0.78838174]), array([0.92237443, 0.9382716 ]), array([0.9502156 , 0.85682074]), array([1314,  405]))
# Bons résultats 1592
# Erreurs: 127
# Avec max_depth= 9
# [[1221   93]
#  [  25  380]]
# (array([0.97993579, 0.80338266]), array([0.92922374, 0.9382716 ]), array([0.95390625, 0.86560364]), array([1314,  405]))
# Bons résultats 1601
# Erreurs: 118
# Avec max_depth= 10
# [[1224   90]
#  [  24  381]]
# (array([0.98076923, 0.8089172 ]), array([0.93150685, 0.94074074]), array([0.95550351, 0.86986301]), array([1314,  405]))
# Bons résultats 1605
# Erreurs: 114
# Avec max_depth= 11
# [[1233   81]
#  [  25  380]]
# (array([0.98012719, 0.82429501]), array([0.93835616, 0.9382716 ]), array([0.95878694, 0.87759815]), array([1314,  405]))
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth= 12
# [[1235   79]
#  [  22  383]]
# (array([0.98249801, 0.82900433]), array([0.93987823, 0.94567901]), array([0.96071567, 0.88350634]), array([1314,  405]))
# Bons résultats 1618
# Erreurs: 101
# Avec max_depth= 13
# [[1235   79]
#  [  22  383]]
# (array([0.98249801, 0.82900433]), array([0.93987823, 0.94567901]), array([0.96071567, 0.88350634]), array([1314,  405]))
# Bons résultats 1618
# Erreurs: 101
# Avec max_depth= 14
# [[1250   64]
#  [  32  373]]
# (array([0.975039  , 0.85354691]), array([0.95129376, 0.92098765]), array([0.96302003, 0.88598575]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 15
# [[1250   64]
#  [  27  378]]
# (array([0.9788567 , 0.85520362]), array([0.95129376, 0.93333333]), array([0.96487843, 0.89256198]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 16
# [[1247   67]
#  [  32  373]]
# (array([0.97498045, 0.84772727]), array([0.94901065, 0.92098765]), array([0.96182029, 0.88284024]), array([1314,  405]))
# Bons résultats 1620
# Erreurs: 99
# Avec max_depth= 17
# [[1242   72]
#  [  30  375]]
# (array([0.97641509, 0.83892617]), array([0.94520548, 0.92592593]), array([0.96055684, 0.88028169]), array([1314,  405]))
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth= 18
# [[1245   69]
#  [  31  374]]
# (array([0.97570533, 0.84424379]), array([0.94748858, 0.92345679]), array([0.96138996, 0.88207547]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 19
# [[1254   60]
#  [  38  367]]
# (array([0.97058824, 0.85948478]), array([0.9543379 , 0.90617284]), array([0.96239447, 0.88221154]), array([1314,  405]))
# Bons résultats 1621
# Erreurs: 98
# Avec max_depth= 20
# [[1249   65]
#  [  32  373]]
# (array([0.97501952, 0.85159817]), array([0.95053272, 0.92098765]), array([0.96262042, 0.88493476]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 21
# [[1256   58]
#  [  33  372]]
# (array([0.97439876, 0.86511628]), array([0.95585997, 0.91851852]), array([0.96504034, 0.89101796]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 22
# [[1254   60]
#  [  37  368]]
# (array([0.97134005, 0.85981308]), array([0.9543379 , 0.90864198]), array([0.96276392, 0.88355342]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 23
# [[1257   57]
#  [  30  375]]
# (array([0.97668998, 0.86805556]), array([0.956621  , 0.92592593]), array([0.96655133, 0.89605735]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 24
# [[1263   51]
#  [  31  374]]
# (array([0.97604328, 0.88      ]), array([0.96118721, 0.92345679]), array([0.96855828, 0.90120482]), array([1314,  405]))
# Bons résultats 1637
# Erreurs: 82
# Avec max_depth= 25
# [[1252   62]
#  [  37  368]]
# (array([0.97129558, 0.85581395]), array([0.95281583, 0.90864198]), array([0.96196696, 0.88143713]), array([1314,  405]))
# Bons résultats 1620
# Erreurs: 99
# Avec max_depth= 26
# [[1257   57]
#  [  30  375]]
# (array([0.97668998, 0.86805556]), array([0.956621  , 0.92592593]), array([0.96655133, 0.89605735]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 27
# [[1255   59]
#  [  35  370]]
# (array([0.97286822, 0.86247086]), array([0.95509893, 0.91358025]), array([0.96390169, 0.88729017]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 28
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 29
# [[1254   60]
#  [  32  373]]
# (array([0.97511664, 0.86143187]), array([0.9543379 , 0.92098765]), array([0.96461538, 0.8902148 ]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 30
# [[1256   58]
#  [  35  370]]
# (array([0.97288923, 0.86448598]), array([0.95585997, 0.91358025]), array([0.96429942, 0.88835534]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 31
# [[1255   59]
#  [  29  376]]
# (array([0.97741433, 0.86436782]), array([0.95509893, 0.92839506]), array([0.96612779, 0.8952381 ]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 32
# [[1255   59]
#  [  36  369]]
# (array([0.97211464, 0.86214953]), array([0.95509893, 0.91111111]), array([0.96353167, 0.88595438]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 33
# [[1258   56]
#  [  33  372]]
# (array([0.97443842, 0.86915888]), array([0.95738204, 0.91851852]), array([0.96583493, 0.89315726]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 34
# [[1261   53]
#  [  33  372]]
# (array([0.97449768, 0.87529412]), array([0.95966514, 0.91851852]), array([0.96702454, 0.89638554]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 35
# [[1249   65]
#  [  35  370]]
# (array([0.97274143, 0.85057471]), array([0.95053272, 0.91358025]), array([0.96150885, 0.88095238]), array([1314,  405]))
# Bons résultats 1619
# Erreurs: 100
# Avec max_depth= 36
# [[1256   58]
#  [  31  374]]
# (array([0.97591298, 0.86574074]), array([0.95585997, 0.92345679]), array([0.96578239, 0.89366786]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 37
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 38
# [[1252   62]
#  [  27  378]]
# (array([0.97888976, 0.85909091]), array([0.95281583, 0.93333333]), array([0.96567682, 0.89467456]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 39
# [[1257   57]
#  [  39  366]]
# (array([0.96990741, 0.86524823]), array([0.956621 , 0.9037037]), array([0.96321839, 0.88405797]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 40
# [[1260   54]
#  [  29  376]]
# (array([0.97750194, 0.8744186 ]), array([0.95890411, 0.92839506]), array([0.96811371, 0.9005988 ]), array([1314,  405]))
# Bons résultats 1636
# Erreurs: 83
# Avec max_depth= 41
# [[1260   54]
#  [  36  369]]
# (array([0.97222222, 0.87234043]), array([0.95890411, 0.91111111]), array([0.96551724, 0.89130435]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 42
# [[1257   57]
#  [  37  368]]
# (array([0.97140649, 0.86588235]), array([0.956621  , 0.90864198]), array([0.96395706, 0.88674699]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 43
# [[1255   59]
#  [  35  370]]
# (array([0.97286822, 0.86247086]), array([0.95509893, 0.91358025]), array([0.96390169, 0.88729017]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 44
# [[1258   56]
#  [  37  368]]
# (array([0.97142857, 0.86792453]), array([0.95738204, 0.90864198]), array([0.96435416, 0.88781665]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 45
# [[1260   54]
#  [  37  368]]
# (array([0.97147263, 0.87203791]), array([0.95890411, 0.90864198]), array([0.96514745, 0.88996372]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 46
# [[1256   58]
#  [  34  371]]
# (array([0.97364341, 0.86480186]), array([0.95585997, 0.91604938]), array([0.96466974, 0.88968825]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 47
# [[1257   57]
#  [  38  367]]
# (array([0.97065637, 0.86556604]), array([0.956621  , 0.90617284]), array([0.96358758, 0.8854041 ]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 48
# [[1261   53]
#  [  32  373]]
# (array([0.97525135, 0.87558685]), array([0.95966514, 0.92098765]), array([0.96739547, 0.8977136 ]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 49
# [[1257   57]
#  [  29  376]]
# (array([0.97744946, 0.86836028]), array([0.956621  , 0.92839506]), array([0.96692308, 0.8973747 ]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 50
# [[1256   58]
#  [  39  366]]
# (array([0.96988417, 0.86320755]), array([0.95585997, 0.9037037 ]), array([0.962821  , 0.88299156]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 51
# [[1262   52]
#  [  32  373]]
# (array([0.97527048, 0.87764706]), array([0.96042618, 0.92098765]), array([0.96779141, 0.89879518]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 52
# [[1258   56]
#  [  28  377]]
# (array([0.97822706, 0.87066975]), array([0.95738204, 0.9308642 ]), array([0.96769231, 0.89976134]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 53
# [[1251   63]
#  [  27  378]]
# (array([0.97887324, 0.85714286]), array([0.95205479, 0.93333333]), array([0.96527778, 0.89361702]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 54
# [[1257   57]
#  [  31  374]]
# (array([0.97593168, 0.86774942]), array([0.956621  , 0.92345679]), array([0.96617986, 0.89473684]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 55
# [[1259   55]
#  [  35  370]]
# (array([0.97295209, 0.87058824]), array([0.95814307, 0.91358025]), array([0.9654908 , 0.89156627]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 56
# [[1262   52]
#  [  38  367]]
# (array([0.97076923, 0.87589499]), array([0.96042618, 0.90617284]), array([0.96557001, 0.8907767 ]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 57
# [[1255   59]
#  [  30  375]]
# (array([0.9766537, 0.8640553]), array([0.95509893, 0.92592593]), array([0.96575606, 0.89392133]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 58
# [[1259   55]
#  [  33  372]]
# (array([0.9744582 , 0.87119438]), array([0.95814307, 0.91851852]), array([0.96623177, 0.89423077]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 59
# [[1253   61]
#  [  30  375]]
# (array([0.9766173 , 0.86009174]), array([0.95357686, 0.92592593]), array([0.96495957, 0.89179548]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 60
# [[1252   62]
#  [  32  373]]
# (array([0.97507788, 0.85747126]), array([0.95281583, 0.92098765]), array([0.96381832, 0.88809524]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 61
# [[1252   62]
#  [  30  375]]
# (array([0.97659906, 0.85812357]), array([0.95281583, 0.92592593]), array([0.96456086, 0.89073634]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 62
# [[1258   56]
#  [  38  367]]
# (array([0.97067901, 0.86761229]), array([0.95738204, 0.90617284]), array([0.96398467, 0.88647343]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 63
# [[1260   54]
#  [  39  366]]
# (array([0.96997691, 0.87142857]), array([0.95890411, 0.9037037 ]), array([0.96440873, 0.88727273]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 64
# [[1256   58]
#  [  38  367]]
# (array([0.97063369, 0.86352941]), array([0.95585997, 0.90617284]), array([0.96319018, 0.88433735]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 65
# [[1251   63]
#  [  32  373]]
# (array([0.97505846, 0.85550459]), array([0.95205479, 0.92098765]), array([0.96341933, 0.88703924]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 66
# [[1251   63]
#  [  33  372]]
# (array([0.97429907, 0.85517241]), array([0.95205479, 0.91851852]), array([0.9630485 , 0.88571429]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 67
# [[1256   58]
#  [  34  371]]
# (array([0.97364341, 0.86480186]), array([0.95585997, 0.91604938]), array([0.96466974, 0.88968825]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 68
# [[1266   48]
#  [  44  361]]
# (array([0.96641221, 0.88264059]), array([0.96347032, 0.89135802]), array([0.96493902, 0.88697789]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 69
# [[1247   67]
#  [  28  377]]
# (array([0.97803922, 0.8490991 ]), array([0.94901065, 0.9308642 ]), array([0.9633063 , 0.88810365]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 70
# [[1260   54]
#  [  34  371]]
# (array([0.97372488, 0.87294118]), array([0.95890411, 0.91604938]), array([0.96625767, 0.8939759 ]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 71
# [[1255   59]
#  [  32  373]]
# (array([0.97513598, 0.86342593]), array([0.95509893, 0.92098765]), array([0.96501346, 0.89127838]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 72
# [[1255   59]
#  [  35  370]]
# (array([0.97286822, 0.86247086]), array([0.95509893, 0.91358025]), array([0.96390169, 0.88729017]), array([1314,  405]))
# Bons résultats 1625
# Erreurs: 94
# Avec max_depth= 73
# [[1248   66]
#  [  30  375]]
# (array([0.97652582, 0.85034014]), array([0.94977169, 0.92592593]), array([0.96296296, 0.88652482]), array([1314,  405]))
# Bons résultats 1623
# Erreurs: 96
# Avec max_depth= 74
# [[1250   64]
#  [  27  378]]
# (array([0.9788567 , 0.85520362]), array([0.95129376, 0.93333333]), array([0.96487843, 0.89256198]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 75
# [[1254   60]
#  [  31  374]]
# (array([0.97587549, 0.86175115]), array([0.9543379 , 0.92345679]), array([0.96498653, 0.89153754]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 76
# [[1256   58]
#  [  30  375]]
# (array([0.97667185, 0.86605081]), array([0.95585997, 0.92592593]), array([0.96615385, 0.89498807]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 77
# [[1259   55]
#  [  37  368]]
# (array([0.97145062, 0.86997636]), array([0.95814307, 0.90864198]), array([0.96475096, 0.88888889]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 78
# [[1255   59]
#  [  25  380]]
# (array([0.98046875, 0.86560364]), array([0.95509893, 0.9382716 ]), array([0.96761758, 0.90047393]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 79
# [[1255   59]
#  [  28  377]]
# (array([0.97817615, 0.8646789 ]), array([0.95509893, 0.9308642 ]), array([0.96649981, 0.89655172]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 80
# [[1254   60]
#  [  30  375]]
# (array([0.97663551, 0.86206897]), array([0.9543379 , 0.92592593]), array([0.96535797, 0.89285714]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 81
# [[1255   59]
#  [  33  372]]
# (array([0.97437888, 0.86310905]), array([0.95509893, 0.91851852]), array([0.96464258, 0.88995215]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 82
# [[1255   59]
#  [  34  371]]
# (array([0.97362296, 0.8627907 ]), array([0.95509893, 0.91604938]), array([0.96427199, 0.88862275]), array([1314,  405]))
# Bons résultats 1626
# Erreurs: 93
# Avec max_depth= 83
# [[1260   54]
#  [  31  374]]
# (array([0.97598761, 0.87383178]), array([0.95890411, 0.92345679]), array([0.96737044, 0.89795918]), array([1314,  405]))
# Bons résultats 1634
# Erreurs: 85
# Avec max_depth= 84
# [[1257   57]
#  [  34  371]]
# (array([0.97366383, 0.86682243]), array([0.956621  , 0.91604938]), array([0.96506718, 0.8907563 ]), array([1314,  405]))
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth= 85
# [[1254   60]
#  [  37  368]]
# (array([0.97134005, 0.85981308]), array([0.9543379 , 0.90864198]), array([0.96276392, 0.88355342]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97
# Avec max_depth= 86
# [[1257   57]
#  [  25  380]]
# (array([0.98049922, 0.86956522]), array([0.956621 , 0.9382716]), array([0.96841294, 0.90261283]), array([1314,  405]))
# Bons résultats 1637
# Erreurs: 82
# Avec max_depth= 87
# [[1257   57]
#  [  33  372]]
# (array([0.9744186 , 0.86713287]), array([0.956621  , 0.91851852]), array([0.96543779, 0.89208633]), array([1314,  405]))
# Bons résultats 1629
# Erreurs: 90
# Avec max_depth= 88
# [[1252   62]
#  [  33  372]]
# (array([0.97431907, 0.85714286]), array([0.95281583, 0.91851852]), array([0.96344748, 0.88676996]), array([1314,  405]))
# Bons résultats 1624
# Erreurs: 95
# Avec max_depth= 89
# [[1256   58]
#  [  31  374]]
# (array([0.97591298, 0.86574074]), array([0.95585997, 0.92345679]), array([0.96578239, 0.89366786]), array([1314,  405]))
# Bons résultats 1630
# Erreurs: 89
# Avec max_depth= 90
# [[1259   55]
#  [  29  376]]
# (array([0.97748447, 0.87238979]), array([0.95814307, 0.92839506]), array([0.96771714, 0.89952153]), array([1314,  405]))
# Bons résultats 1635
# Erreurs: 84
# Avec max_depth= 91
# [[1254   60]
#  [  44  361]]
# (array([0.96610169, 0.85748219]), array([0.9543379 , 0.89135802]), array([0.96018377, 0.87409201]), array([1314,  405]))
# Bons résultats 1615
# Erreurs: 104
# Avec max_depth= 92
# [[1258   56]
#  [  31  374]]
# (array([0.97595035, 0.86976744]), array([0.95738204, 0.92345679]), array([0.96657703, 0.89580838]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 93
# [[1258   56]
#  [  30  375]]
# (array([0.97670807, 0.87006961]), array([0.95738204, 0.92592593]), array([0.9669485 , 0.89712919]), array([1314,  405]))
# Bons résultats 1633
# Erreurs: 86
# Avec max_depth= 94
# [[1263   51]
#  [  41  364]]
# (array([0.96855828, 0.87710843]), array([0.96118721, 0.89876543]), array([0.96485867, 0.88780488]), array([1314,  405]))
# Bons résultats 1627
# Erreurs: 92
# Avec max_depth= 95
# [[1254   60]
#  [  28  377]]
# (array([0.97815913, 0.86270023]), array([0.9543379, 0.9308642]), array([0.96610169, 0.89548694]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 96
# [[1246   68]
#  [  34  371]]
# (array([0.9734375 , 0.84510251]), array([0.94824962, 0.91604938]), array([0.96067849, 0.87914692]), array([1314,  405]))
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth= 97
# [[1256   58]
#  [  29  376]]
# (array([0.97743191, 0.86635945]), array([0.95585997, 0.92839506]), array([0.96652559, 0.89630513]), array([1314,  405]))
# Bons résultats 1632
# Erreurs: 87
# Avec max_depth= 98
# [[1263   51]
#  [  37  368]]
# (array([0.97153846, 0.87828162]), array([0.96118721, 0.90864198]), array([0.96633512, 0.89320388]), array([1314,  405]))
# Bons résultats 1631
# Erreurs: 88
# Avec max_depth= 99
# [[1254   60]
#  [  37  368]]
# (array([0.97134005, 0.85981308]), array([0.9543379 , 0.90864198]), array([0.96276392, 0.88355342]), array([1314,  405]))
# Bons résultats 1622
# Erreurs: 97

# %%
# pour ces trois derniers paramètres on ne passe jamais sous la barre des 85 erreurs.

# %% [markdown]
# ### Autres caracétristiques

# %%
import statistics

X_stylo = []#notre nouvelle matrice de description
for text in data_spam["text"]:
    liste_mots = text.split()
    phrases = text.split(". ")
    NB_phrases = len(phrases)
    NB_mots = len(liste_mots)
    NB_caracteres = len(text)
    moyenne_taille_mots = statistics.mean([len(x) for x in liste_mots])
    moyenne_taille_phrases = NB_mots/NB_phrases
    caracteristiques = [NB_phrases, NB_mots, NB_caracteres, moyenne_taille_mots, moyenne_taille_phrases]
    X_stylo.append(caracteristiques)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_stylo, y, test_size=0.3, random_state=0)
DT = tree.DecisionTreeClassifier()
DT = DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)
matrice_confusion = confusion_matrix(y_test, y_pred)
print(matrice_confusion)
stats = precision_recall_fscore_support(y_test, y_pred)
print(stats)
report = classification_report(y_test, y_pred, target_names=nom_classes)
print(report)
# Out:
# [[1103  211]
#  [ 199  206]]
# (array([0.84715822, 0.4940048 ]), array([0.83942161, 0.50864198]), array([0.84327217, 0.50121655]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.85      0.84      0.84      1314
#         spam       0.49      0.51      0.50       405
#
#     accuracy                           0.76      1719
#    macro avg       0.67      0.67      0.67      1719
# weighted avg       0.76      0.76      0.76      1719

# %%
y_spam = [1 for x in y_test]##une liste remplie de 1
report = classification_report(y_test, y_spam, target_names=nom_classes)
matrice_confusion = confusion_matrix(y_test, y_spam)

y_ham = [0 for x in y_test]##une liste remplie de 0
report = classification_report(y_test, y_ham, target_names=nom_classes)
matrice_confusion = confusion_matrix(y_test, y_ham)
print(matrice_confusion)
print(report)
# Out:
# [[1314    0]
#  [ 405    0]]
#               precision    recall  f1-score   support
#
#          ham       0.76      1.00      0.87      1314
#         spam       0.00      0.00      0.00       405
#
#     accuracy                           0.76      1719
#    macro avg       0.38      0.50      0.43      1719
# weighted avg       0.58      0.76      0.66      1719
# /home/alexj/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Et maintenant on combine le BOW et le stylométrique**

# %%
## on regarde la "forme" de X
print(X.shape[0])#NB lignes   -> instances
print(X.shape[1])#Nb colonnes -> caractéristiques

##on crée une sparse matrix avec notre X_stylo
from scipy.sparse import csr_matrix
sparse_stylo = csr_matrix(X_stylo)
print(sparse_stylo.shape[0])#NB lignes   -> instances
print(sparse_stylo.shape[1])#Nb colonnes -> caractéristiques

## on a le même nombre de ligne, on fait donc une conctaténation horizontale :
from scipy.sparse import hstack
X_fusion = hstack((X, sparse_stylo))
# Out:
# 5728
# 375535
# 5728
# 5

# %% [markdown]
# **Résultats:**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_fusion, y, test_size=0.3, random_state=0)
DT = tree.DecisionTreeClassifier()
DT = DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)
matrice_confusion = confusion_matrix(y_test, y_pred)
print(matrice_confusion)
stats = precision_recall_fscore_support(y_test, y_pred)
print(stats)
report = classification_report(y_test, y_pred, target_names=nom_classes)
print(report)
print('Bons résultats %d' % (y_test == y_pred).sum())
print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# [[1258   56]
#  [  36  369]]
# (array([0.97217929, 0.86823529]), array([0.95738204, 0.91111111]), array([0.96472393, 0.88915663]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.97      0.96      0.96      1314
#         spam       0.87      0.91      0.89       405
#
#     accuracy                           0.95      1719
#    macro avg       0.92      0.93      0.93      1719
# weighted avg       0.95      0.95      0.95      1719
#
# Bons résultats 1627
# Erreurs: 92

# %%
#résultats moyens

# %% [markdown]
# ## Autres classifieurs

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

import warnings 
warnings.filterwarnings("ignore")

LR = LogisticRegression()
RDF = RandomForestClassifier()
SVC = SVC()
KN = KNeighborsClassifier()

Liste = [LR, RDF, SVC, KN]

# %%
for i in Liste:
    i = i.fit(X_train, y_train)
    y_pred = i.predict(X_test)
    matrice_confusion = confusion_matrix(y_test, y_pred)
    print(i)
    print(matrice_confusion)
    stats = precision_recall_fscore_support(y_test, y_pred)
    print(stats)
    report = classification_report(y_test, y_pred, target_names=nom_classes)
    print(report)
    print('Bons résultats %d' % (y_test == y_pred).sum())
    print('Erreurs: %d' % (y_test != y_pred).sum())
    print("-"*10)
# Out:
# LogisticRegression()
# [[1306    8]
#  [  14  391]]
# (array([0.98939394, 0.97994987]), array([0.99391172, 0.9654321 ]), array([0.99164768, 0.97263682]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99      1314
#         spam       0.98      0.97      0.97       405
#
#     accuracy                           0.99      1719
#    macro avg       0.98      0.98      0.98      1719
# weighted avg       0.99      0.99      0.99      1719
#
# Bons résultats 1697
# Erreurs: 22
# ----------
# RandomForestClassifier()
# [[1313    1]
#  [ 103  302]]
# (array([0.92725989, 0.99669967]), array([0.99923896, 0.74567901]), array([0.96190476, 0.85310734]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.93      1.00      0.96      1314
#         spam       1.00      0.75      0.85       405
#
#     accuracy                           0.94      1719
#    macro avg       0.96      0.87      0.91      1719
# weighted avg       0.94      0.94      0.94      1719
#
# Bons résultats 1615
# Erreurs: 104
# ----------
# SVC()
# [[1310    4]
#  [  79  326]]
# (array([0.94312455, 0.98787879]), array([0.99695586, 0.80493827]), array([0.96929338, 0.88707483]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.94      1.00      0.97      1314
#         spam       0.99      0.80      0.89       405
#
#     accuracy                           0.95      1719
#    macro avg       0.97      0.90      0.93      1719
# weighted avg       0.95      0.95      0.95      1719
#
# Bons résultats 1636
# Erreurs: 83
# ----------
# KNeighborsClassifier()
# [[1309    5]
#  [ 190  215]]
# (array([0.87324883, 0.97727273]), array([0.99619482, 0.5308642 ]), array([0.93067899, 0.688     ]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.87      1.00      0.93      1314
#         spam       0.98      0.53      0.69       405
#
#     accuracy                           0.89      1719
#    macro avg       0.93      0.76      0.81      1719
# weighted avg       0.90      0.89      0.87      1719
#
# Bons résultats 1524
# Erreurs: 195
# ----------

# %%
# très bons résultats avec le LogisticRegression : ce sont les meilleurs obtenus jusqu'à maintenant

# %% [markdown]
# ### En faisant varier les n-grammes

# %%
for min_N in range(1, 2):
  for max_N in range(min_N, 9):
    V = CountVectorizer(ngram_range = (min_N, max_N), analyzer = "char")
    X = V.fit_transform(data_spam["text"])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
    print(f"Ngram_range : ({min_N}, {max_N})")
    for i in Liste:
        clf = i.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        print('%s classifier : %.4f'%(i, score))
# Out:
# Ngram_range : (1, 1)
# LogisticRegression() classifier : 0.8947
# RandomForestClassifier() classifier : 0.9244
# SVC() classifier : 0.7859
# KNeighborsClassifier() classifier : 0.8662
# Ngram_range : (1, 2)
# LogisticRegression() classifier : 0.9581
# RandomForestClassifier() classifier : 0.9471
# SVC() classifier : 0.7882
# KNeighborsClassifier() classifier : 0.8912
# Ngram_range : (1, 3)
# LogisticRegression() classifier : 0.9761
# RandomForestClassifier() classifier : 0.9564
# SVC() classifier : 0.8080
# KNeighborsClassifier() classifier : 0.9133
# Ngram_range : (1, 4)
# LogisticRegression() classifier : 0.9820
# RandomForestClassifier() classifier : 0.9651
# SVC() classifier : 0.8173
# KNeighborsClassifier() classifier : 0.9197
# Ngram_range : (1, 5)
# LogisticRegression() classifier : 0.9820
# RandomForestClassifier() classifier : 0.9657
# SVC() classifier : 0.8226
# KNeighborsClassifier() classifier : 0.9267
# Ngram_range : (1, 6)
# LogisticRegression() classifier : 0.9843
# RandomForestClassifier() classifier : 0.9604
# SVC() classifier : 0.8296
# KNeighborsClassifier() classifier : 0.9273
# Ngram_range : (1, 7)
# LogisticRegression() classifier : 0.9831
# RandomForestClassifier() classifier : 0.9639
# SVC() classifier : 0.8330
# KNeighborsClassifier() classifier : 0.9302
# Ngram_range : (1, 8)
# LogisticRegression() classifier : 0.9837
# RandomForestClassifier() classifier : 0.9610
# SVC() classifier : 0.8348
# KNeighborsClassifier() classifier : 0.9319

# %% [markdown]
# ### Forêt aléatoire : zoom sur quelques paramètres

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
    # On fait la somme de tous les cas où la valeur dans y_test est bien trouvée dans y_pred
print('Bons résultats %d' % (y_test == y_pred).sum())
print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# Bons résultats 1637
# Erreurs: 82

# %%
# ci-dessus : paramètres par défaut

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

for i in range(1,100):
    clf = RandomForestClassifier(max_depth=i, random_state=0)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    # On fait la somme de tous les cas où la valeur dans y_test est bien trouvée dans y_pred
    print("Avec max_depth =", i)
    print('Bons résultats %d' % (y_test == y_pred).sum())
    print('Erreurs: %d' % (y_test != y_pred).sum())
# Out:
# Avec max_depth = 1
# Bons résultats 1314
# Erreurs: 405
# Avec max_depth = 2
# Bons résultats 1314
# Erreurs: 405
# Avec max_depth = 3
# Bons résultats 1316
# Erreurs: 403
# Avec max_depth = 4
# Bons résultats 1329
# Erreurs: 390
# Avec max_depth = 5
# Bons résultats 1338
# Erreurs: 381
# Avec max_depth = 6
# Bons résultats 1353
# Erreurs: 366
# Avec max_depth = 7
# Bons résultats 1385
# Erreurs: 334
# Avec max_depth = 8
# Bons résultats 1388
# Erreurs: 331
# Avec max_depth = 9
# Bons résultats 1391
# Erreurs: 328
# Avec max_depth = 10
# Bons résultats 1411
# Erreurs: 308
# Avec max_depth = 11
# Bons résultats 1414
# Erreurs: 305
# Avec max_depth = 12
# Bons résultats 1424
# Erreurs: 295
# Avec max_depth = 13
# Bons résultats 1430
# Erreurs: 289
# Avec max_depth = 14
# Bons résultats 1436
# Erreurs: 283
# Avec max_depth = 15
# Bons résultats 1447
# Erreurs: 272
# Avec max_depth = 16
# Bons résultats 1458
# Erreurs: 261
# Avec max_depth = 17
# Bons résultats 1460
# Erreurs: 259
# Avec max_depth = 18
# Bons résultats 1468
# Erreurs: 251
# Avec max_depth = 19
# Bons résultats 1476
# Erreurs: 243
# Avec max_depth = 20
# Bons résultats 1482
# Erreurs: 237
# Avec max_depth = 21
# Bons résultats 1492
# Erreurs: 227
# Avec max_depth = 22
# Bons résultats 1499
# Erreurs: 220
# Avec max_depth = 23
# Bons résultats 1513
# Erreurs: 206
# Avec max_depth = 24
# Bons résultats 1516
# Erreurs: 203
# Avec max_depth = 25
# Bons résultats 1523
# Erreurs: 196
# Avec max_depth = 26
# Bons résultats 1523
# Erreurs: 196
# Avec max_depth = 27
# Bons résultats 1531
# Erreurs: 188
# Avec max_depth = 28
# Bons résultats 1533
# Erreurs: 186
# Avec max_depth = 29
# Bons résultats 1535
# Erreurs: 184
# Avec max_depth = 30
# Bons résultats 1534
# Erreurs: 185
# Avec max_depth = 31
# Bons résultats 1545
# Erreurs: 174
# Avec max_depth = 32
# Bons résultats 1550
# Erreurs: 169
# Avec max_depth = 33
# Bons résultats 1550
# Erreurs: 169
# Avec max_depth = 34
# Bons résultats 1550
# Erreurs: 169
# Avec max_depth = 35
# Bons résultats 1556
# Erreurs: 163
# Avec max_depth = 36
# Bons résultats 1559
# Erreurs: 160
# Avec max_depth = 37
# Bons résultats 1559
# Erreurs: 160
# Avec max_depth = 38
# Bons résultats 1558
# Erreurs: 161
# Avec max_depth = 39
# Bons résultats 1573
# Erreurs: 146
# Avec max_depth = 40
# Bons résultats 1571
# Erreurs: 148
# Avec max_depth = 41
# Bons résultats 1569
# Erreurs: 150
# Avec max_depth = 42
# Bons résultats 1568
# Erreurs: 151
# Avec max_depth = 43
# Bons résultats 1576
# Erreurs: 143
# Avec max_depth = 44
# Bons résultats 1580
# Erreurs: 139
# Avec max_depth = 45
# Bons résultats 1581
# Erreurs: 138
# Avec max_depth = 46
# Bons résultats 1584
# Erreurs: 135
# Avec max_depth = 47
# Bons résultats 1577
# Erreurs: 142
# Avec max_depth = 48
# Bons résultats 1588
# Erreurs: 131
# Avec max_depth = 49
# Bons résultats 1584
# Erreurs: 135
# Avec max_depth = 50
# Bons résultats 1586
# Erreurs: 133
# Avec max_depth = 51
# Bons résultats 1595
# Erreurs: 124
# Avec max_depth = 52
# Bons résultats 1594
# Erreurs: 125
# Avec max_depth = 53
# Bons résultats 1593
# Erreurs: 126
# Avec max_depth = 54
# Bons résultats 1593
# Erreurs: 126
# Avec max_depth = 55
# Bons résultats 1591
# Erreurs: 128
# Avec max_depth = 56
# Bons résultats 1592
# Erreurs: 127
# Avec max_depth = 57
# Bons résultats 1599
# Erreurs: 120
# Avec max_depth = 58
# Bons résultats 1599
# Erreurs: 120
# Avec max_depth = 59
# Bons résultats 1599
# Erreurs: 120
# Avec max_depth = 60
# Bons résultats 1600
# Erreurs: 119
# Avec max_depth = 61
# Bons résultats 1601
# Erreurs: 118
# Avec max_depth = 62
# Bons résultats 1602
# Erreurs: 117
# Avec max_depth = 63
# Bons résultats 1600
# Erreurs: 119
# Avec max_depth = 64
# Bons résultats 1604
# Erreurs: 115
# Avec max_depth = 65
# Bons résultats 1605
# Erreurs: 114
# Avec max_depth = 66
# Bons résultats 1598
# Erreurs: 121
# Avec max_depth = 67
# Bons résultats 1608
# Erreurs: 111
# Avec max_depth = 68
# Bons résultats 1607
# Erreurs: 112
# Avec max_depth = 69
# Bons résultats 1599
# Erreurs: 120
# Avec max_depth = 70
# Bons résultats 1607
# Erreurs: 112
# Avec max_depth = 71
# Bons résultats 1602
# Erreurs: 117
# Avec max_depth = 72
# Bons résultats 1611
# Erreurs: 108
# Avec max_depth = 73
# Bons résultats 1608
# Erreurs: 111
# Avec max_depth = 74
# Bons résultats 1614
# Erreurs: 105
# Avec max_depth = 75
# Bons résultats 1610
# Erreurs: 109
# Avec max_depth = 76
# Bons résultats 1611
# Erreurs: 108
# Avec max_depth = 77
# Bons résultats 1611
# Erreurs: 108
# Avec max_depth = 78
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth = 79
# Bons résultats 1609
# Erreurs: 110
# Avec max_depth = 80
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth = 81
# Bons résultats 1614
# Erreurs: 105
# Avec max_depth = 82
# Bons résultats 1609
# Erreurs: 110
# Avec max_depth = 83
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth = 84
# Bons résultats 1610
# Erreurs: 109
# Avec max_depth = 85
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth = 86
# Bons résultats 1606
# Erreurs: 113
# Avec max_depth = 87
# Bons résultats 1608
# Erreurs: 111
# Avec max_depth = 88
# Bons résultats 1612
# Erreurs: 107
# Avec max_depth = 89
# Bons résultats 1610
# Erreurs: 109
# Avec max_depth = 90
# Bons résultats 1611
# Erreurs: 108
# Avec max_depth = 91
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth = 92
# Bons résultats 1618
# Erreurs: 101
# Avec max_depth = 93
# Bons résultats 1613
# Erreurs: 106
# Avec max_depth = 94
# Bons résultats 1617
# Erreurs: 102
# Avec max_depth = 95
# Bons résultats 1628
# Erreurs: 91
# Avec max_depth = 96
# Bons résultats 1620
# Erreurs: 99
# Avec max_depth = 97
# Bons résultats 1616
# Erreurs: 103
# Avec max_depth = 98
# Bons résultats 1618
# Erreurs: 101
# Avec max_depth = 99
# Bons résultats 1616
# Erreurs: 103

# %%
# amélioration des résultats jusqu'à max_depth = 95, puis augmentation du nombre d'erreurs
# mais moins bons résultats qu'avec les paramètres par défaut

# %% [markdown]
# ### En supprimant la ponctuation et les stopwords

# %%
# rappels pour la cellule ci-après (ces éléments de codes ont été exécutés plus avant)
# LR = LogisticRegression()
# RDF = RandomForestClassifier()
# SVC = SVC()
# KN = KNeighborsClassifier()
# Liste = [LR, RDF, SVC, KN]

# %%
from nltk.corpus import stopwords

# %%
import re

# %%
def remove_ponctuation(chaine):
    ponctuations = [",", "'", '"', "-", "\."]
    for stopword in ponctuations:
        chaine = re.sub(f" {stopword} ", " ", chaine)
    return chaine

# %%
def remove_stopwords(chaine):
    final_stopwords_list = stopwords.words('english')
    s = chaine
    for stopword in final_stopwords_list:
        chaine = re.sub(f" {stopword} ", " ", chaine)
    return chaine

# %%
for pretraitement in ["stopwords", "ponctuation"]:
    if pretraitement =="stopwords":
        liste_pretraite = [remove_stopwords(j) for j in texte]
        X = V.fit_transform(liste_pretraite)
    elif pretraitement =="ponctuation":
        liste_titres_pretraite = [remove_ponctuation(j) for j in texte]
        X = V.fit_transform(liste_pretraite)    
    else:
        X = V.fit_transform(texte)
    for split_size in [0.3]: #[0.1, 0.2, 0.3, 0.9]:
        print(f"Split_size : {split_size}, Pretraitement: {pretraitement}")
    #découpage train VS test
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = split_size, random_state=0)
    ##classification
        for i in Liste:
            i = i.fit(X_train, y_train)
            y_pred = i.predict(X_test)
            matrice_confusion = confusion_matrix(y_test, y_pred)
            print(i)
            print(matrice_confusion)
            stats = precision_recall_fscore_support(y_test, y_pred)
            print(stats)
            report = classification_report(y_test, y_pred, target_names=nom_classes)
            print(report)
            print('Bons résultats %d' % (y_test == y_pred).sum())
            print('Erreurs: %d' % (y_test != y_pred).sum())
            print ('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
            print("-"*10)
# Out:
# Split_size : 0.3, Pretraitement: stopwords
# LogisticRegression()
# [[1306    8]
#  [  12  393]]
# (array([0.9908953 , 0.98004988]), array([0.99391172, 0.97037037]), array([0.99240122, 0.9751861 ]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99      1314
#         spam       0.98      0.97      0.98       405
#
#     accuracy                           0.99      1719
#    macro avg       0.99      0.98      0.98      1719
# weighted avg       0.99      0.99      0.99      1719
#
# Bons résultats 1699
# Erreurs: 20
# Accuracy: 0.99
# ----------
# Accuracy: 0.99
# RandomForestClassifier()
# [[1308    6]
#  [  36  369]]
# (array([0.97321429, 0.984     ]), array([0.99543379, 0.91111111]), array([0.98419865, 0.94615385]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98      1314
#         spam       0.98      0.91      0.95       405
#
#     accuracy                           0.98      1719
#    macro avg       0.98      0.95      0.97      1719
# weighted avg       0.98      0.98      0.98      1719
#
# Bons résultats 1677
# Erreurs: 42
# Accuracy: 0.98
# ----------
# Accuracy: 0.98
# SVC()
# [[1305    9]
#  [  37  368]]
# (array([0.97242921, 0.97612732]), array([0.99315068, 0.90864198]), array([0.98268072, 0.94117647]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.97      0.99      0.98      1314
#         spam       0.98      0.91      0.94       405
#
#     accuracy                           0.97      1719
#    macro avg       0.97      0.95      0.96      1719
# weighted avg       0.97      0.97      0.97      1719
#
# Bons résultats 1673
# Erreurs: 46
# Accuracy: 0.97
# ----------
# Accuracy: 0.97
# KNeighborsClassifier()
# [[1293   21]
#  [ 161  244]]
# (array([0.88927098, 0.92075472]), array([0.98401826, 0.60246914]), array([0.93424855, 0.72835821]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.89      0.98      0.93      1314
#         spam       0.92      0.60      0.73       405
#
#     accuracy                           0.89      1719
#    macro avg       0.91      0.79      0.83      1719
# weighted avg       0.90      0.89      0.89      1719
#
# Bons résultats 1537
# Erreurs: 182
# Accuracy: 0.89
# ----------
# Accuracy: 0.89
# Split_size : 0.3, Pretraitement: ponctuation
# LogisticRegression()
# [[1306    8]
#  [  12  393]]
# (array([0.9908953 , 0.98004988]), array([0.99391172, 0.97037037]), array([0.99240122, 0.9751861 ]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99      1314
#         spam       0.98      0.97      0.98       405
#
#     accuracy                           0.99      1719
#    macro avg       0.99      0.98      0.98      1719
# weighted avg       0.99      0.99      0.99      1719
#
# Bons résultats 1699
# Erreurs: 20
# Accuracy: 0.99
# ----------
# Accuracy: 0.99
# RandomForestClassifier()
# [[1311    3]
#  [  40  365]]
# (array([0.9703923 , 0.99184783]), array([0.99771689, 0.90123457]), array([0.98386492, 0.94437257]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98      1314
#         spam       0.99      0.90      0.94       405
#
#     accuracy                           0.97      1719
#    macro avg       0.98      0.95      0.96      1719
# weighted avg       0.98      0.97      0.97      1719
#
# Bons résultats 1676
# Erreurs: 43
# Accuracy: 0.97
# ----------
# Accuracy: 0.97
# SVC()
# [[1305    9]
#  [  37  368]]
# (array([0.97242921, 0.97612732]), array([0.99315068, 0.90864198]), array([0.98268072, 0.94117647]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.97      0.99      0.98      1314
#         spam       0.98      0.91      0.94       405
#
#     accuracy                           0.97      1719
#    macro avg       0.97      0.95      0.96      1719
# weighted avg       0.97      0.97      0.97      1719
#
# Bons résultats 1673
# Erreurs: 46
# Accuracy: 0.97
# ----------
# Accuracy: 0.97
# KNeighborsClassifier()
# [[1293   21]
#  [ 161  244]]
# (array([0.88927098, 0.92075472]), array([0.98401826, 0.60246914]), array([0.93424855, 0.72835821]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.89      0.98      0.93      1314
#         spam       0.92      0.60      0.73       405
#
#     accuracy                           0.89      1719
#    macro avg       0.91      0.79      0.83      1719
# weighted avg       0.90      0.89      0.89      1719
#
# Bons résultats 1537
# Erreurs: 182
# Accuracy: 0.89
# ----------
# Accuracy: 0.89

# %%
# idem :

# %%
from sklearn.metrics import accuracy_score

liste_pretraite = [remove_ponctuation(j) for j in texte]
X = V.fit_transform(liste_pretraite)    
for split_size in [0.3]:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = split_size, random_state=0)

for i in Liste:
    i = i.fit(X_train, y_train)
    y_pred = i.predict(X_test)
    matrice_confusion = confusion_matrix(y_test, y_pred)
    print(i)
    print(matrice_confusion)
    stats = precision_recall_fscore_support(y_test, y_pred)
    print(stats)
    report = classification_report(y_test, y_pred, target_names=nom_classes)
    print(report)
    print('Bons résultats %d' % (y_test == y_pred).sum())
    print('Erreurs: %d' % (y_test != y_pred).sum())
    print ('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
    print("-"*10)
#print(corpus_sans_stopwords)
# Out:
# LogisticRegression()
# [[1305    9]
#  [  11  394]]
# (array([0.99164134, 0.97766749]), array([0.99315068, 0.97283951]), array([0.99239544, 0.97524752]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99      1314
#         spam       0.98      0.97      0.98       405
#
#     accuracy                           0.99      1719
#    macro avg       0.98      0.98      0.98      1719
# weighted avg       0.99      0.99      0.99      1719
#
# Bons résultats 1699
# Erreurs: 20
# Accuracy: 0.99
# ----------
# RandomForestClassifier()
# [[1312    2]
#  [  58  347]]
# (array([0.95766423, 0.99426934]), array([0.99847793, 0.85679012]), array([0.97764531, 0.9204244 ]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98      1314
#         spam       0.99      0.86      0.92       405
#
#     accuracy                           0.97      1719
#    macro avg       0.98      0.93      0.95      1719
# weighted avg       0.97      0.97      0.96      1719
#
# Bons résultats 1659
# Erreurs: 60
# Accuracy: 0.97
# ----------
# SVC()
# [[1307    7]
#  [  72  333]]
# (array([0.94778825, 0.97941176]), array([0.99467275, 0.82222222]), array([0.97066469, 0.89395973]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.95      0.99      0.97      1314
#         spam       0.98      0.82      0.89       405
#
#     accuracy                           0.95      1719
#    macro avg       0.96      0.91      0.93      1719
# weighted avg       0.96      0.95      0.95      1719
#
# Bons résultats 1640
# Erreurs: 79
# Accuracy: 0.95
# ----------
# KNeighborsClassifier()
# [[1299   15]
#  [ 146  259]]
# (array([0.89896194, 0.94525547]), array([0.98858447, 0.63950617]), array([0.94164552, 0.7628866 ]), array([1314,  405]))
#               precision    recall  f1-score   support
#
#          ham       0.90      0.99      0.94      1314
#         spam       0.95      0.64      0.76       405
#
#     accuracy                           0.91      1719
#    macro avg       0.92      0.81      0.85      1719
# weighted avg       0.91      0.91      0.90      1719
#
# Bons résultats 1558
# Erreurs: 161
# Accuracy: 0.91
# ----------

# %%
#LogisticRegression est le classifieur qui obtient à nouveau le meilleur résultat et 
#ils sont mêmes meilleurs que précédemment

# %%
# accuracy commence à baisser à partir de split-size = 0.5
# faire varier eta0 ne change pas le résultat
